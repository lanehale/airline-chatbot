# %% [markdown]
# <a href="https://colab.research.google.com/github/lanehale/airline-chatbot/blob/main/create_query_intent_booking_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Upload flight delay data
# !ls
# Out:
# Airline_Delay_Cause.csv  sample_data

# %%
# Create a dictionary of unique carrier codes and names
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('Airline_Delay_Cause.csv')

# Create a DF of unique carriers only
unique_airlines = df[['carrier', 'carrier_name']].drop_duplicates()

# Create a dictionary of unique carriers
airline_dict = dict(zip(unique_airlines['carrier'], unique_airlines['carrier_name']))

# Display the unique carriers DF
unique_airlines.head()
# Out:
#     carrier            carrier_name
# 0        9E       Endeavor Air Inc.
# 92       AA  American Airlines Inc.
# 220      AS    Alaska Airlines Inc.
# 308      B6         JetBlue Airways
# 376      DL    Delta Air Lines Inc.

# %%
# Display the shape of the unique carriers DF
unique_airlines.shape
# Out:
# (23, 2)

# %%
# Display the unique carriers DF
unique_airlines
# Out:
#        carrier                  carrier_name
# 0           9E             Endeavor Air Inc.
# 92          AA        American Airlines Inc.
# 220         AS          Alaska Airlines Inc.
# 308         B6               JetBlue Airways
# 376         DL          Delta Air Lines Inc.
# 515         F9        Frontier Airlines Inc.
# 592         G4                 Allegiant Air
# 714         HA        Hawaiian Airlines Inc.
# 735         MQ                     Envoy Air
# 866         NK              Spirit Air Lines
# 929         OH             PSA Airlines Inc.
# 1018        OO         SkyWest Airlines Inc.
# 1259        UA         United Air Lines Inc.
# 1369        WN        Southwest Airlines Co.
# 1476        YX              Republic Airline
# 13612       QX                   Horizon Air
# 13873       YV            Mesa Airlines Inc.
# 57614       EV       ExpressJet Airlines LLC
# 87808       EV      ExpressJet Airlines Inc.
# 109094      VX                Virgin America
# 144993      US               US Airways Inc.
# 151536      FL   AirTran Airways Corporation
# 162048      MQ  American Eagle Airlines Inc.

# %%
# Display the first five dictionary keys
list(airline_dict.keys())[:5]
# Out:
# ['9E', 'AA', 'AS', 'B6', 'DL']

# %%
# Display the airline dictionary size, keys and values
len(airline_dict), airline_dict
# Out:
# (21,
#  {'9E': 'Endeavor Air Inc.',
#   'AA': 'American Airlines Inc.',
#   'AS': 'Alaska Airlines Inc.',
#   'B6': 'JetBlue Airways',
#   'DL': 'Delta Air Lines Inc.',
#   'F9': 'Frontier Airlines Inc.',
#   'G4': 'Allegiant Air',
#   'HA': 'Hawaiian Airlines Inc.',
#   'MQ': 'American Eagle Airlines Inc.',
#   'NK': 'Spirit Air Lines',
#   'OH': 'PSA Airlines Inc.',
#   'OO': 'SkyWest Airlines Inc.',
#   'UA': 'United Air Lines Inc.',
#   'WN': 'Southwest Airlines Co.',
#   'YX': 'Republic Airline',
#   'QX': 'Horizon Air',
#   'YV': 'Mesa Airlines Inc.',
#   'EV': 'ExpressJet Airlines Inc.',
#   'VX': 'Virgin America',
#   'US': 'US Airways Inc.',
#   'FL': 'AirTran Airways Corporation'})

# %%
# Take out 'Inc.', 'Co.' and 'Corp'
for key, value in airline_dict.items():
  idx = value.find('Inc')
  if idx != -1:
    airline_dict[key] = value[:idx-1]
  else:
    idx = value.find('Co')
    if idx != -1:
      airline_dict[key] = value[:idx-1]

# Split airline names
for key, value in airline_dict.items():
  airline_dict[key] = value.split()

airline_dict
# Out:
# {'9E': ['Endeavor', 'Air'],
#  'AA': ['American', 'Airlines'],
#  'AS': ['Alaska', 'Airlines'],
#  'B6': ['JetBlue', 'Airways'],
#  'DL': ['Delta', 'Air', 'Lines'],
#  'F9': ['Frontier', 'Airlines'],
#  'G4': ['Allegiant', 'Air'],
#  'HA': ['Hawaiian', 'Airlines'],
#  'MQ': ['American', 'Eagle', 'Airlines'],
#  'NK': ['Spirit', 'Air', 'Lines'],
#  'OH': ['PSA', 'Airlines'],
#  'OO': ['SkyWest', 'Airlines'],
#  'UA': ['United', 'Air', 'Lines'],
#  'WN': ['Southwest', 'Airlines'],
#  'YX': ['Republic', 'Airline'],
#  'QX': ['Horizon', 'Air'],
#  'YV': ['Mesa', 'Airlines'],
#  'EV': ['ExpressJet', 'Airlines'],
#  'VX': ['Virgin', 'America'],
#  'US': ['US', 'Airways'],
#  'FL': ['AirTran', 'Airways']}

# %%
# Make 'American Eagle' one string
one_str = airline_dict['MQ'][0] + ' ' + airline_dict['MQ'][1]
airline_dict['MQ'][0] = one_str
del airline_dict['MQ'][1]

# Make 'Air Lines' one string to match csv data and maybe help training
one_str = airline_dict['DL'][1] + ' ' + airline_dict['DL'][2]
airline_dict['DL'][1] = one_str
del airline_dict['DL'][2]

one_str = airline_dict['UA'][1] + ' ' + airline_dict['UA'][2]
airline_dict['UA'][1] = one_str
del airline_dict['UA'][2]

one_str = airline_dict['NK'][1] + ' ' + airline_dict['NK'][2]
airline_dict['NK'][1] = one_str
del airline_dict['NK'][2]

airline_dict
# Out:
# {'9E': ['Endeavor', 'Air'],
#  'AA': ['American', 'Airlines'],
#  'AS': ['Alaska', 'Airlines'],
#  'B6': ['JetBlue', 'Airways'],
#  'DL': ['Delta', 'Air Lines'],
#  'F9': ['Frontier', 'Airlines'],
#  'G4': ['Allegiant', 'Air'],
#  'HA': ['Hawaiian', 'Airlines'],
#  'MQ': ['American Eagle', 'Airlines'],
#  'NK': ['Spirit', 'Air Lines'],
#  'OH': ['PSA', 'Airlines'],
#  'OO': ['SkyWest', 'Airlines'],
#  'UA': ['United', 'Air Lines'],
#  'WN': ['Southwest', 'Airlines'],
#  'YX': ['Republic', 'Airline'],
#  'QX': ['Horizon', 'Air'],
#  'YV': ['Mesa', 'Airlines'],
#  'EV': ['ExpressJet', 'Airlines'],
#  'VX': ['Virgin', 'America'],
#  'US': ['US', 'Airways'],
#  'FL': ['AirTran', 'Airways']}

# %%
# Create a list of carrier codes
carrier_codes = list(airline_dict.keys())
carrier_codes
# Out:
# ['9E',
#  'AA',
#  'AS',
#  'B6',
#  'DL',
#  'F9',
#  'G4',
#  'HA',
#  'MQ',
#  'NK',
#  'OH',
#  'OO',
#  'UA',
#  'WN',
#  'YX',
#  'QX',
#  'YV',
#  'EV',
#  'VX',
#  'US',
#  'FL']

# %%
# Create a DF of unique airports only
unique_airports = df[['airport', 'airport_name']].drop_duplicates()

# Create a dictionary of unique airports
airport_dict = dict(zip(unique_airports['airport'], unique_airports['airport_name']))

# Display the unique airports DF
unique_airports
# Out:
#        airport                                       airport_name
# 0          ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...
# 1          ABY             Albany, GA: Southwest Georgia Regional
# 2          AEX           Alexandria, LA: Alexandria International
# 3          AGS        Augusta, GA: Augusta Regional at Bush Field
# 4          ALB                   Albany, NY: Albany International
# ...        ...                                                ...
# 151732     CIC                         Chico, CA: Chico Municipal
# 154943     FOE                        Topeka, KS: Topeka Regional
# 158861     LMT    Klamath Falls, OR: Crater Lake Klamath Regional
# 158864     MOD  Modesto, CA: Modesto City-County-Harry Sham Field
# 167202     IYK                     Inyokern, CA: Inyokern Airport
#
# [419 rows x 2 columns]

# %%
# Display the airport dictionary size, keys and values
len(airport_dict), airport_dict
# Out:
# (395,
#  {'ABE': 'Allentown/Bethlehem/Easton, PA: Lehigh Valley International',
#   'ABY': 'Albany, GA: Southwest Georgia Regional',
#   'AEX': 'Alexandria, LA: Alexandria International',
#   'AGS': 'Augusta, GA: Augusta Regional at Bush Field',
#   'ALB': 'Albany, NY: Albany International',
#   'ATL': 'Atlanta, GA: Hartsfield-Jackson Atlanta International',
#   'AUS': 'Austin, TX: Austin - Bergstrom International',
#   'AVL': 'Asheville, NC: Asheville Regional',
#   'AZO': 'Kalamazoo, MI: Kalamazoo/Battle Creek International',
#   'BDL': 'Hartford, CT: Bradley International',
#   'BGM': 'Binghamton, NY: Greater Binghamton/Edwin A. Link Field',
#   'BGR': 'Bangor, ME: Bangor International',
#   'BHM': 'Birmingham, AL: Birmingham-Shuttlesworth International',
#   'BNA': 'Nashville, TN: Nashville International',
#   'BQK': 'Brunswick, GA: Brunswick Golden Isles',
#   'BTV': 'Burlington, VT: Burlington International',
#   'BUF': 'Buffalo, NY: Buffalo Niagara International',
#   'BWI': 'Baltimore, MD: Baltimore/Washington International Thurgood Marshall',
#   'CAE': 'Columbia, SC: Columbia Metropolitan',
#   'CHA': 'Chattanooga, TN: Lovell Field',
#   'CHO': 'Charlottesville, VA: Charlottesville Albemarle',
#   'CHS': 'Charleston, SC: Charleston AFB/International',
#   'CLE': 'Cleveland, OH: Cleveland-Hopkins International',
#   'CLT': 'Charlotte, NC: Charlotte Douglas International',
#   'CMH': 'Columbus, OH: John Glenn Columbus International',
#   'CRW': 'Charleston/Dunbar, WV: Yeager',
#   'CSG': 'Columbus, GA: Columbus Airport',
#   'CVG': 'Cincinnati, OH: Cincinnati/Northern Kentucky International',
#   'CWA': 'Mosinee, WI: Central Wisconsin',
#   'DAY': 'Dayton, OH: James M Cox/Dayton International',
#   'DCA': 'Washington, DC: Ronald Reagan Washington National',
#   'DHN': 'Dothan, AL: Dothan Regional',
#   'DLH': 'Duluth, MN: Duluth International',
#   'DSM': 'Des Moines, IA: Des Moines International',
#   'DTW': 'Detroit, MI: Detroit Metro Wayne County',
#   'EVV': 'Evansville, IN: Evansville Regional',
#   'EWR': 'Newark, NJ: Newark Liberty International',
#   'FAR': 'Fargo, ND: Hector International',
#   'FAY': 'Fayetteville, NC: Fayetteville Regional/Grannis Field',
#   'FSD': 'Sioux Falls, SD: Joe Foss Field',
#   'GFK': 'Grand Forks, ND: Grand Forks International',
#   'GRR': 'Grand Rapids, MI: Gerald R. Ford International',
#   'GSO': 'Greensboro/High Point, NC: Piedmont Triad International',
#   'GSP': 'Greer, SC: Greenville-Spartanburg International',
#   'GTR': 'Columbus, MS: Golden Triangle Regional',
#   'IAD': 'Washington, DC: Washington Dulles International',
#   'ILM': 'Wilmington, NC: Wilmington International',
#   'IND': 'Indianapolis, IN: Indianapolis International',
#   'ITH': 'Ithaca/Cortland, NY: Ithaca Tompkins Regional',
#   'JAX': 'Jacksonville, FL: Jacksonville International',
#   'JFK': 'New York, NY: John F. Kennedy International',
#   'LAN': 'Lansing, MI: Capital Region International',
#   'LEX': 'Lexington, KY: Blue Grass',
#   'LFT': 'Lafayette, LA: Lafayette Regional Paul Fournet Field',
#   'LGA': 'New York, NY: LaGuardia',
#   'LIT': 'Little Rock, AR: Bill and Hillary Clinton Nat Adams Field',
#   'MBS': 'Saginaw/Bay City/Midland, MI: MBS International',
#   'MCI': 'Kansas City, MO: Kansas City International',
#   'MEM': 'Memphis, TN: Memphis International',
#   'MGM': 'Montgomery, AL: Montgomery Regional',
#   'MKE': 'Milwaukee, WI: General Mitchell International',
#   'MLI': 'Moline, IL: Quad City International',
#   'MLU': 'Monroe, LA: Monroe Regional',
#   'MOB': 'Mobile, AL: Mobile Regional',
#   'MQT': 'Marquette, MI: Sawyer International',
#   'MSN': 'Madison, WI: Dane County Regional-Truax Field',
#   'MSP': 'Minneapolis, MN: Minneapolis-St Paul International',
#   'MYR': 'Myrtle Beach, SC: Myrtle Beach International',
#   'OAJ': 'Jacksonville/Camp Lejeune, NC: Albert J Ellis',
#   'OMA': 'Omaha, NE: Eppley Airfield',
#   'ORF': 'Norfolk, VA: Norfolk International',
#   'ORH': 'Worcester, MA: Worcester Regional',
#   'PIT': 'Pittsburgh, PA: Pittsburgh International',
#   'PVD': 'Providence, RI: Theodore Francis Green State',
#   'PWM': 'Portland, ME: Portland International Jetport',
#   'RAP': 'Rapid City, SD: Rapid City Regional',
#   'RDU': 'Raleigh/Durham, NC: Raleigh-Durham International',
#   'RIC': 'Richmond, VA: Richmond International',
#   'ROA': 'Roanoke, VA: Roanoke Blacksburg Regional Woodrum Field',
#   'ROC': 'Rochester, NY: Greater Rochester International',
#   'RST': 'Rochester, MN: Rochester International',
#   'SAV': 'Savannah, GA: Savannah/Hilton Head International',
#   'SDF': 'Louisville, KY: Louisville Muhammad Ali International',
#   'SHV': 'Shreveport, LA: Shreveport Regional',
#   'STL': 'St. Louis, MO: St Louis Lambert International',
#   'SYR': 'Syracuse, NY: Syracuse Hancock International',
#   'TLH': 'Tallahassee, FL: Tallahassee International',
#   'TRI': 'Bristol/Johnson City/Kingsport, TN: Tri Cities',
#   'TVC': 'Traverse City, MI: Cherry Capital',
#   'TYS': 'Knoxville, TN: McGhee Tyson',
#   'VLD': 'Valdosta, GA: Valdosta Regional',
#   'XNA': 'Fayetteville, AR: Northwest Arkansas Regional',
#   'ABQ': 'Albuquerque, NM: Albuquerque International Sunport',
#   'AMA': 'Amarillo, TX: Rick Husband Amarillo International',
#   'ANC': 'Anchorage, AK: Ted Stevens Anchorage International',
#   'AVP': 'Scranton/Wilkes-Barre, PA: Wilkes Barre Scranton International',
#   'BFL': 'Bakersfield, CA: Meadows Field',
#   'BOI': 'Boise, ID: Boise Air Terminal',
#   'BOS': 'Boston, MA: Logan International',
#   'BUR': 'Burbank, CA: Bob Hope',
#   'BZN': 'Bozeman, MT: Bozeman Yellowstone International',
#   'CID': 'Cedar Rapids/Iowa City, IA: The Eastern Iowa',
#   'COS': 'Colorado Springs, CO: City of Colorado Springs Municipal',
#   'DAB': 'Daytona Beach, FL: Daytona Beach International',
#   'DEN': 'Denver, CO: Denver International',
#   'DFW': 'Dallas/Fort Worth, TX: Dallas/Fort Worth International',
#   'DRO': 'Durango, CO: Durango La Plata County',
#   'ECP': 'Panama City, FL: Northwest Florida Beaches International',
#   'EGE': 'Eagle, CO: Eagle County Regional',
#   'ELP': 'El Paso, TX: El Paso International',
#   'EUG': 'Eugene, OR: Mahlon Sweet Field',
#   'EYW': 'Key West, FL: Key West International',
#   'FAT': 'Fresno, CA: Fresno Yosemite International',
#   'FCA': 'Kalispell, MT: Glacier Park International',
#   'FLL': 'Fort Lauderdale, FL: Fort Lauderdale-Hollywood International',
#   'GEG': 'Spokane, WA: Spokane International',
#   'HNL': 'Honolulu, HI: Daniel K Inouye International',
#   'HSV': 'Huntsville, AL: Huntsville International-Carl T Jones Field',
#   'IAH': 'Houston, TX: George Bush Intercontinental/Houston',
#   'ICT': 'Wichita, KS: Wichita Dwight D Eisenhower National',
#   'JAC': 'Jackson, WY: Jackson Hole',
#   'KOA': 'Kona, HI: Ellison Onizuka Kona International at Keahole',
#   'LAS': 'Las Vegas, NV: McCarran International',
#   'LAX': 'Los Angeles, CA: Los Angeles International',
#   'LBB': 'Lubbock, TX: Lubbock Preston Smith International',
#   'LIH': 'Lihue, HI: Lihue Airport',
#   'MCO': 'Orlando, FL: Orlando International',
#   'MDT': 'Harrisburg, PA: Harrisburg International',
#   'MFE': 'Mission/McAllen/Edinburg, TX: McAllen Miller International',
#   'MHT': 'Manchester, NH: Manchester-Boston Regional',
#   'MIA': 'Miami, FL: Miami International',
#   'MRY': 'Monterey, CA: Monterey Regional',
#   'MSO': 'Missoula, MT: Missoula International',
#   'MSY': 'New Orleans, LA: Louis Armstrong New Orleans International',
#   'MTJ': 'Montrose/Delta, CO: Montrose Regional',
#   'OGG': 'Kahului, HI: Kahului Airport',
#   'OKC': 'Oklahoma City, OK: Will Rogers World',
#   'ONT': 'Ontario, CA: Ontario International',
#   'ORD': "Chicago, IL: Chicago O'Hare International",
#   'PBI': 'West Palm Beach/Palm Beach, FL: Palm Beach International',
#   'PDX': 'Portland, OR: Portland International',
#   'PHL': 'Philadelphia, PA: Philadelphia International',
#   'PHX': 'Phoenix, AZ: Phoenix Sky Harbor International',
#   'PNS': 'Pensacola, FL: Pensacola International',
#   'PSP': 'Palm Springs, CA: Palm Springs International',
#   'RNO': 'Reno, NV: Reno/Tahoe International',
#   'RSW': 'Fort Myers, FL: Southwest Florida International',
#   'SAN': 'San Diego, CA: San Diego International',
#   'SAT': 'San Antonio, TX: San Antonio International',
#   'SBA': 'Santa Barbara, CA: Santa Barbara Municipal',
#   'SBP': 'San Luis Obispo, CA: San Luis County Regional',
#   'SEA': 'Seattle, WA: Seattle/Tacoma International',
#   'SFO': 'San Francisco, CA: San Francisco International',
#   'SJC': 'San Jose, CA: Norman Y. Mineta San Jose International',
#   'SJU': 'San Juan, PR: Luis Munoz Marin International',
#   'SLC': 'Salt Lake City, UT: Salt Lake City International',
#   'SMF': 'Sacramento, CA: Sacramento International',
#   'SNA': 'Santa Ana, CA: John Wayne Airport-Orange County',
#   'SRQ': 'Sarasota/Bradenton, FL: Sarasota/Bradenton International',
#   'STT': 'Charlotte Amalie, VI: Cyril E King',
#   'STX': 'Christiansted, VI: Henry E. Rohlsen',
#   'TPA': 'Tampa, FL: Tampa International',
#   'TUL': 'Tulsa, OK: Tulsa International',
#   'TUS': 'Tucson, AZ: Tucson International',
#   'VPS': 'Valparaiso, FL: Eglin AFB Destin Fort Walton Beach',
#   'ADK': 'Adak Island, AK: Adak',
#   'ADQ': 'Kodiak, AK: Kodiak Airport',
#   'AKN': 'King Salmon, AK: King Salmon Airport',
#   'BET': 'Bethel, AK: Bethel Airport',
#   'BRW': 'Barrow, AK: Wiley Post/Will Rogers Memorial',
#   'CDV': 'Cordova, AK: Merle K Mudhole Smith',
#   'DAL': 'Dallas, TX: Dallas Love Field',
#   'DLG': 'Dillingham, AK: Dillingham Airport',
#   'FAI': 'Fairbanks, AK: Fairbanks International',
#   'GST': 'Gustavus, AK: Gustavus Airport',
#   'JNU': 'Juneau, AK: Juneau International',
#   'KTN': 'Ketchikan, AK: Ketchikan International',
#   'OAK': 'Oakland, CA: Metropolitan Oakland International',
#   'OME': 'Nome, AK: Nome Airport',
#   'OTZ': 'Kotzebue, AK: Ralph Wien Memorial',
#   'PSC': 'Pasco/Kennewick/Richland, WA: Tri Cities',
#   'PSG': 'Petersburg, AK: Petersburg James A Johnson',
#   'RDM': 'Bend/Redmond, OR: Roberts Field',
#   'SCC': 'Deadhorse, AK: Deadhorse Airport',
#   'SIT': 'Sitka, AK: Sitka Rocky Gutierrez',
#   'STS': 'Santa Rosa, CA: Charles M. Schulz - Sonoma County',
#   'WRG': 'Wrangell, AK: Wrangell Airport',
#   'YAK': 'Yakutat, AK: Yakutat Airport',
#   'ACK': 'Nantucket, MA: Nantucket Memorial',
#   'BQN': 'Aguadilla, PR: Rafael Hernandez',
#   'HPN': 'White Plains, NY: Westchester County',
#   'HYA': 'Hyannis, MA: Barnstable Municipal-Boardman/Polando Field',
#   'MVY': "Martha's Vineyard, MA: Martha's Vineyard Airport",
#   'PSE': 'Ponce, PR: Mercedita',
#   'ATW': 'Appleton, WI: Appleton International',
#   'BIL': 'Billings, MT: Billings Logan International',
#   'BIS': 'Bismarck/Mandan, ND: Bismarck Municipal',
#   'BTR': 'Baton Rouge, LA: Baton Rouge Metropolitan/Ryan Field',
#   'GNV': 'Gainesville, FL: Gainesville Regional',
#   'GPT': 'Gulfport/Biloxi, MS: Gulfport-Biloxi International',
#   'GRB': 'Green Bay, WI: Green Bay Austin Straubel International',
#   'HOU': 'Houston, TX: William P Hobby',
#   'JAN': 'Jackson/Vicksburg, MS: Jackson Medgar Wiley Evers International',
#   'MDW': 'Chicago, IL: Chicago Midway International',
#   'MLB': 'Melbourne, FL: Melbourne International',
#   'SGF': 'Springfield, MO: Springfield-Branson National',
#   'BMI': 'Bloomington/Normal, IL: Central Il Regional Airport at Bloomington',
#   'ISP': 'Islip, NY: Long Island MacArthur',
#   'TTN': 'Trenton, NJ: Trenton Mercer',
#   'AZA': 'Phoenix, AZ: Phoenix - Mesa Gateway',
#   'BLI': 'Bellingham, WA: Bellingham International',
#   'BLV': 'Belleville, IL: Scott AFB/MidAmerica',
#   'CAK': 'Akron, OH: Akron-Canton Regional',
#   'CKB': 'Clarksburg/Fairmont, WV: North Central West Virginia',
#   'ELM': 'Elmira/Corning, NY: Elmira/Corning Regional',
#   'FNT': 'Flint, MI: Bishop International',
#   'FWA': 'Fort Wayne, IN: Fort Wayne International',
#   'GJT': 'Grand Junction, CO: Grand Junction Regional',
#   'GRI': 'Grand Island, NE: Central Nebraska Regional',
#   'GTF': 'Great Falls, MT: Great Falls International',
#   'HGR': 'Hagerstown, MD: Hagerstown Regional-Richard A. Henson Field',
#   'HTS': 'Ashland, WV: Tri-State/Milton J. Ferguson Field',
#   'IAG': 'Niagara Falls, NY: Niagara Falls International',
#   'IDA': 'Idaho Falls, ID: Idaho Falls Regional',
#   'LCK': 'Columbus, OH: Rickenbacker International',
#   'LRD': 'Laredo, TX: Laredo International',
#   'MFR': 'Medford, OR: Rogue Valley International - Medford',
#   'MOT': 'Minot, ND: Minot International',
#   'PBG': 'Plattsburgh, NY: Plattsburgh International',
#   'PGD': 'Punta Gorda, FL: Punta Gorda Airport',
#   'PIA': 'Peoria, IL: General Downing - Peoria International',
#   'PIE': 'St. Petersburg, FL: St Pete Clearwater International',
#   'PSM': 'Portsmouth, NH: Portsmouth International at Pease',
#   'PVU': 'Provo, UT: Provo Municipal',
#   'RFD': 'Rockford, IL: Chicago/Rockford International',
#   'SBN': 'South Bend, IN: South Bend International',
#   'SCK': 'Stockton, CA: Stockton Metropolitan',
#   'SFB': 'Sanford, FL: Orlando Sanford International',
#   'SMX': 'Santa Maria, CA: Santa Maria Public/Capt. G. Allan Hancock Field',
#   'SPI': 'Springfield, IL: Abraham Lincoln Capital',
#   'SWF': 'Newburgh/Poughkeepsie, NY: New York Stewart International',
#   'TOL': 'Toledo, OH: Toledo Express',
#   'USA': 'Concord, NC: Concord Padgett Regional',
#   'ITO': 'Hilo, HI: Hilo International',
#   'LGB': 'Long Beach, CA: Long Beach Airport',
#   'PPG': 'Pago Pago, TT: Pago Pago International',
#   'ABI': 'Abilene, TX: Abilene Regional',
#   'BRO': 'Brownsville, TX: Brownsville South Padre Island International',
#   'CLL': 'College Station/Bryan, TX: Easterwood Field',
#   'CMI': 'Champaign/Urbana, IL: University of Illinois/Willard',
#   'COU': 'Columbia, MO: Columbia Regional',
#   'CRP': 'Corpus Christi, TX: Corpus Christi International',
#   'FSM': 'Fort Smith, AR: Fort Smith Regional',
#   'GRK': 'Killeen, TX: Robert Gray AAF',
#   'HHH': 'Hilton Head, SC: Hilton Head Airport',
#   'HRL': 'Harlingen/San Benito, TX: Valley International',
#   'MAF': 'Midland/Odessa, TX: Midland International Air and Space Port',
#   'SJT': 'San Angelo, TX: San Angelo Regional/Mathis Field',
#   'YUM': 'Yuma, AZ: Yuma MCAS/Yuma International',
#   'ACY': 'Atlantic City, NJ: Atlantic City International',
#   'LBE': 'Latrobe, PA: Arnold Palmer Regional',
#   'EWN': 'New Bern/Morehead/Beaufort, NC: Coastal Carolina Regional',
#   'ABR': 'Aberdeen, SD: Aberdeen Regional',
#   'ACT': 'Waco, TX: Waco Regional',
#   'ACV': 'Arcata/Eureka, CA: California Redwood Coast Humboldt County',
#   'ALW': 'Walla Walla, WA: Walla Walla Regional',
#   'APN': 'Alpena, MI: Alpena County Regional',
#   'ASE': 'Aspen, CO: Aspen Pitkin County Sardy Field',
#   'BFF': 'Scottsbluff, NE: Western Neb. Regional/William B. Heilig Field',
#   'BIH': 'Bishop, CA: Bishop Airport',
#   'BJI': 'Bemidji, MN: Bemidji Regional',
#   'BPT': 'Beaumont/Port Arthur, TX: Jack Brooks Regional',
#   'BRD': 'Brainerd, MN: Brainerd Lakes Regional',
#   'BTM': 'Butte, MT: Bert Mooney',
#   'CDC': 'Cedar City, UT: Cedar City Regional',
#   'CIU': 'Sault Ste. Marie, MI: Chippewa County International',
#   'CMX': 'Hancock/Houghton, MI: Houghton County Memorial',
#   'CNY': 'Moab, UT: Canyonlands Field',
#   'CPR': 'Casper, WY: Casper/Natrona County International',
#   'DDC': 'Dodge City, KS: Dodge City Regional',
#   'DEC': 'Decatur, IL: Decatur Airport',
#   'DIK': 'Dickinson, ND: Dickinson - Theodore Roosevelt Regional',
#   'DVL': 'Devils Lake, ND: Devils Lake Regional',
#   'EKO': 'Elko, NV: Elko Regional',
#   'ESC': 'Escanaba, MI: Delta County',
#   'FLG': 'Flagstaff, AZ: Flagstaff Pulliam',
#   'FOD': 'Fort Dodge, IA: Fort Dodge Regional',
#   'GCC': 'Gillette, WY: Gillette Campbell County',
#   'GCK': 'Garden City, KS: Garden City Regional',
#   'GGG': 'Longview, TX: East Texas Regional',
#   'GUC': 'Gunnison, CO: Gunnison-Crested Butte Regional',
#   'HDN': 'Hayden, CO: Yampa Valley',
#   'HIB': 'Hibbing, MN: Range Regional',
#   'HLN': 'Helena, MT: Helena Regional',
#   'HYS': 'Hays, KS: Hays Regional',
#   'IMT': 'Iron Mountain/Kingsfd, MI: Ford',
#   'INL': 'International Falls, MN: Falls International Einarson Field',
#   'JLN': 'Joplin, MO: Joplin Regional',
#   'JMS': 'Jamestown, ND: Jamestown Regional',
#   'JST': 'Johnstown, PA: John Murtha Johnstown-Cambria County',
#   'LAR': 'Laramie, WY: Laramie Regional',
#   'LAW': 'Lawton/Fort Sill, OK: Lawton-Fort Sill Regional',
#   'LBF': 'North Platte, NE: North Platte Regional Airport Lee Bird Field',
#   'LBL': 'Liberal, KS: Liberal Mid-America Regional',
#   'LCH': 'Lake Charles, LA: Lake Charles Regional',
#   'LNK': 'Lincoln, NE: Lincoln Airport',
#   'LWS': 'Lewiston, ID: Lewiston Nez Perce County',
#   'MCW': 'Mason City, IA: Mason City Municipal',
#   'MEI': 'Meridian, MS: Key Field',
#   'OTH': 'North Bend/Coos Bay, OR: Southwest Oregon Regional',
#   'PIB': 'Hattiesburg/Laurel, MS: Hattiesburg-Laurel Regional',
#   'PIH': 'Pocatello, ID: Pocatello Regional',
#   'PLN': 'Pellston, MI: Pellston Regional Airport of Emmet County',
#   'PRC': 'Prescott, AZ: Prescott Regional Ernest A Love Field',
#   'RDD': 'Redding, CA: Redding Municipal',
#   'RHI': 'Rhinelander, WI: Rhinelander/Oneida County',
#   'RIW': 'Riverton/Lander, WY: Riverton Regional',
#   'RKS': 'Rock Springs, WY: Southwest Wyoming Regional',
#   'ROW': 'Roswell, NM: Roswell International Air Center',
#   'SAF': 'Santa Fe, NM: Santa Fe Municipal',
#   'SCE': 'State College, PA: University Park',
#   'SGU': 'St. George, UT: St George Regional',
#   'SHR': 'Sheridan, WY: Sheridan County',
#   'SLN': 'Salina, KS: Salina Regional',
#   'SPS': 'Wichita Falls, TX: Sheppard AFB/Wichita Falls Municipal',
#   'SUN': 'Sun Valley/Hailey/Ketchum, ID: Friedman Memorial',
#   'SUX': 'Sioux City, IA: Sioux Gateway Brig Gen Bud Day Field',
#   'SWO': 'Stillwater, OK: Stillwater Regional',
#   'TWF': 'Twin Falls, ID: Joslin Field - Magic Valley Regional',
#   'TXK': 'Texarkana, AR: Texarkana Regional-Webb Field',
#   'TYR': 'Tyler, TX: Tyler Pounds Regional',
#   'VCT': 'Victoria, TX: Victoria Regional',
#   'VEL': 'Vernal, UT: Vernal Regional',
#   'WYS': 'West Yellowstone, MT: Yellowstone',
#   'XWA': 'Williston, ND: Williston Basin International',
#   'GUM': 'Guam, TT: Guam International',
#   'SPN': 'Saipan, TT: Francisco C. Ada Saipan International',
#   'LSE': 'La Crosse, WI: La Crosse Regional',
#   'PAE': 'Everett, WA: Snohomish County',
#   'ERI': 'Erie, PA: Erie International/Tom Ridge Field',
#   'OWB': 'Owensboro, KY: Owensboro Daviess County Regional',
#   'STC': 'St. Cloud, MN: St. Cloud Regional',
#   'MHK': 'Manhattan/Ft. Riley, KS: Manhattan Regional',
#   'PGV': 'Greenville, NC: Pitt Greenville',
#   'COD': 'Cody, WY: Yellowstone Regional',
#   'CYS': 'Cheyenne, WY: Cheyenne Regional/Jerry Olson Field',
#   'DRT': 'Del Rio, TX: Del Rio International',
#   'ALO': 'Waterloo, IA: Waterloo Regional',
#   'PUB': 'Pueblo, CO: Pueblo Memorial',
#   'PHF': 'Newport News/Williamsburg, VA: Newport News/Williamsburg International',
#   'PAH': 'Paducah, KY: Barkley Regional',
#   'EAT': 'Wenatchee, WA: Pangborn Memorial',
#   'PUW': 'Pullman, WA: Pullman Moscow Regional',
#   'YKM': 'Yakima, WA: Yakima Air Terminal/McAllister Field',
#   'FLO': 'Florence, SC: Florence Regional',
#   'EAU': 'Eau Claire, WI: Chippewa Valley Regional',
#   'LYH': 'Lynchburg, VA: Lynchburg Regional/Preston Glenn Field',
#   'CGI': 'Cape Girardeau, MO: Cape Girardeau Regional',
#   'EAR': 'Kearney, NE: Kearney Regional',
#   'LWB': 'Lewisburg, WV: Greenbrier Valley',
#   'SHD': 'Staunton, VA: Shenandoah Valley Regional',
#   'TBN': 'Fort Leonard Wood, MO: Waynesville-St. Robert Regional Forney Field',
#   'IFP': 'Bullhead City, AZ: Laughlin/Bullhead International',
#   'DBQ': 'Dubuque, IA: Dubuque Regional',
#   'MKG': 'Muskegon, MI: Muskegon County',
#   'BKG': 'Branson, MO: Branson Airport',
#   'ILG': 'Wilmington, DE: New Castle',
#   'ALS': 'Alamosa, CO: San Luis Valley Regional/Bergman Field',
#   'HOB': 'Hobbs, NM: Lea County Regional',
#   'OGS': 'Ogdensburg, NY: Ogdensburg International',
#   'OGD': 'Ogden, UT: Ogden-Hinckley',
#   'ATY': 'Watertown, SD: Watertown Regional',
#   'PIR': 'Pierre, SD: Pierre Regional',
#   'HVN': 'New Haven, CT: Tweed New Haven',
#   'CDB': 'Cold Bay, AK: Cold Bay Airport',
#   'IPT': 'Williamsport, PA: Williamsport Regional',
#   'BFM': 'Mobile, AL: Mobile International',
#   'MMH': 'Mammoth Lakes, CA: Mammoth Lakes Airport',
#   'UIN': 'Quincy, IL: Quincy Regional-Baldwin Field',
#   'ISN': 'Williston, ND: Sloulin Field International',
#   'ART': 'Watertown, NY: Watertown International',
#   'YNG': 'Youngstown/Warren, OH: Youngstown-Warren Regional',
#   'FNL': 'Fort Collins/Loveland, CO: Northern Colorado Regional',
#   'UST': 'St. Augustine, FL: Northeast Florida Regional',
#   'TKI': 'Tokeen, AK: Tokeen Airport',
#   'ENV': 'Wendover, UT: Wendover Airport',
#   'EFD': 'Houston, TX: Ellington',
#   'CLD': 'Carlsbad, CA: McClellan-Palomar',
#   'CEC': 'Crescent City, CA: Jack McNamara Field',
#   'MCN': 'Macon, GA: Middle Georgia Regional',
#   'CIC': 'Chico, CA: Chico Municipal',
#   'FOE': 'Topeka, KS: Topeka Regional',
#   'LMT': 'Klamath Falls, OR: Crater Lake Klamath Regional',
#   'MOD': 'Modesto, CA: Modesto City-County-Harry Sham Field',
#   'IYK': 'Inyokern, CA: Inyokern Airport'})

# %%
airport_name = list(airport_dict.values())
airport_name[0]
# Out:
# 'Allentown/Bethlehem/Easton, PA: Lehigh Valley International'

# %%
import re
name_list = re.split(r"[/,]", airport_name[0])
name_list
# Out:
# ['Allentown', 'Bethlehem', 'Easton', ' PA: Lehigh Valley International']

# %%
name_list[0]
# Out:
# 'Allentown'

# %% [markdown]
# ### Upload booking template file to alter

# %%
# Upload query_intent_booking_template.csv data
# !ls
# Out:
# Airline_Delay_Cause.csv  query_intent_booking_template.csv  sample_data

# %%
import csv
import random
from datetime import datetime

airport = list(airport_dict.keys())
airport_name = list(airport_dict.values())

MMM_list = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
MONTH_list = ['January','February','March','April','May','June','July','August','September','October','November','December']
DDth_list = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th','11th','12th','13th','14th','15th','16th','17th','18th','19th','20th','21st','22nd','23rd','24th','25th','26th','27th','28th']
DDD_list = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
WEEKDAY_list = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
NUM_text = ['one','two','three','four','five','six','seven','eight','nine','ten']

# Get current date and time
current_datetime = datetime.now()
current_year = current_datetime.year
current_month = current_datetime.month
current_day = current_datetime.day

# Create a list to save altered csv data
altered_data = [['query','intent']]

# Open the CSV file in read mode ('r')
with open('query_intent_booking_template.csv', 'r', newline='') as csvfile:

  reader = csv.reader(csvfile)  # Create a CSV reader object
  next(reader)  # Skip header
  i = -1        # index for carrier_codes
  cnt = 0       # counter of rows for debugging

  # Iterate through each row in the CSV file
  for row in reader:

    if i < len(carrier_codes) - 1:
      i += 1
    else:
      i = 0

    # Alter the query
    query = row[0].split()

    i1 = random.randint(0, len(airport_dict)-1)
    i2 = random.randint(0, len(airport_dict)-1)

    if 'airptCd1' in query:
      idx = query.index('airptCd1')
      query[idx] = airport[i1]  # Get first airport code
    elif 'airptNm1' in query:
      idx = query.index('airptNm1')
      name_list = re.split(r"[/,]", airport_name[i1])
      query[idx] = name_list[0]  # Get first airport name

    if 'airptCd2' in query:
      idx = query.index('airptCd2')
      query[idx] = airport[i2]  # Get second airport code
    elif 'airptNm2' in query:
      idx = query.index('airptNm2')
      name_list = re.split(r"[/,]", airport_name[i2])
      query[idx] = name_list[0]  # Get second airport name

    if 'MM' in query:
      idx = query.index('MM')
      MM_idx = random.randint(1, 12)
      query[idx] = str(MM_idx)  # Get numeric month
    elif 'MMM' in query:
      idx = query.index('MMM')
      MM_idx = random.randint(1, 12)
      query[idx] = MMM_list[MM_idx-1]  # Get abbreviated month
    elif 'MONTH' in query:
      idx = query.index('MONTH')
      MM_idx = random.randint(1, 12)
      query[idx] = MONTH_list[MM_idx-1]  # Get abbreviated month

    if 'DD' in query:
      idx = query.index('DD')
      high_DD = 31
      if MM_idx == 2:
        high_DD = 28
      elif MM_idx == 4 or MM_idx == 6 or MM_idx == 9 or MM_idx == 11:
        high_DD = 30
      DD_idx = random.randint(1, high_DD)
      query[idx] = str(DD_idx)  # Get numeric date
    elif 'DDth' in query:
      idx = query.index('DDth')
      DD_idx = random.randint(1, 28)
      query[idx] = DDth_list[DD_idx-1]  # Get ordinal date
    elif 'DDD' in query:
      idx = query.index('DDD')
      DDD_idx = random.randint(0, 6)
      query[idx] = DDD_list[DDD_idx]  # Get abbreviated day
    elif 'WEEKDAY' in query:
      idx = query.index('WEEKDAY')
      DDD_idx = random.randint(0, 6)
      query[idx] = WEEKDAY_list[DDD_idx]  # Get abbreviated day

    if 'YY' in query or 'YYYY' in query:
      if (current_month == MM_idx and current_day >= DD_idx) or current_month > MM_idx:
        current_year += 1

      if 'YY' in query:
        idx = query.index('YY')
        query[idx] = str(current_year)[-2:]   # Get last two digits of current year
      else:
        idx = query.index('YYYY')
        query[idx] = str(current_year)  # Get current year

      current_year = current_datetime.year  # reset for next loop

    if 'NUM' in query:
      idx = query.index('NUM')
      NUM_idx = random.randint(0, 9)
      query[idx] = NUM_text[NUM_idx]  # Get number

    if 'CC' in query:
      idx = query.index('CC')
      query[idx] = carrier_codes[i]  # Get carrier code

    if 'Capcxr1' in query:
      idx = query.index('Capcxr1')
      query[idx] = airline_dict[carrier_codes[i]][0]  # Get first name of carrier

    if '9999_' in query:
      idx = query.index('9999_')
      query[idx] = str(random.randint(1, 9999))  # Get a random flight number

    if '9999_?' in query:
      idx = query.index('9999_?')
      query[idx] = str(random.randint(1, 9999)) + '?'  # Get a random flight number

    for _ in range(3):
      if '+-' in query:
        idx = query.index('+-')
        query[idx-1] = query[idx-1] + '-' + query[idx+1]
        del query[idx:idx+2]

    for _ in range(2):
      if '+/' in query:
        idx = query.index('+/')
        query[idx-1] = query[idx-1] + '/' + query[idx+1]
        del query[idx:idx+2]

    joined_query = " ".join(query)
    altered_data.append([joined_query, 'booking'])

    cnt += 1
    #if cnt > 25:
    #  break
    #print(row)

altered_data
# Out:
# [['query', 'intent'],
#  ['Book an early flight from Fort Smith to Cody tomorrow', 'booking'],
#  ['Book an early flight Gulfport to El Paso tomorrow evening', 'booking'],
#  ['Book an early flight Pago Pago - Mobile next Tuesday', 'booking'],
#  ['Book an early flight Fresno-Long Beach next Thu', 'booking'],
#  ['Book an early flight from CLD to Quincy tomorrow night', 'booking'],
#  ['Book a late flight San Juan Lansing the 22nd of next month', 'booking'],
#  ['flight Fayetteville to FSM book next month on the 19th', 'booking'],
#  ['a late flight booking TTN - Aguadilla December 21 please', 'booking'],
#  ['Yakima-BIH book the 2nd of Dec flight', 'booking'],
#  ['Trenton BLI book Jul 10 2025', 'booking'],
#  ['Book anything from IAD to FNL seven days from now', 'booking'],
#  ['Book anything CHA to BNA for 2/11', 'booking'],
#  ['Book anything RDD - SPN on 7/27/25', 'booking'],
#  ['Book anything JAX-SGU on 5-19', 'booking'],
#  ['Book anything ELP HOB for 7-16-25', 'booking'],
#  ['Book a flight from Albany to Jamestown tomorrow', 'booking'],
#  ['Book a flight Austin to Ogdensburg tomorrow evening', 'booking'],
#  ['Book a flight Gustavus - Columbus next Tuesday', 'booking'],
#  ['Get a flight Scottsbluff-Hibbing next Thu', 'booking'],
#  ['Could you get me a flight from BTV to Raleigh tomorrow night', 'booking'],
#  ['Book a seat Lafayette Charleston the 25th of next month', 'booking'],
#  ['Book a seat Charleston to AGS next month on the 9th', 'booking'],
#  ['Get two seats AZO - Burlington September 21', 'booking'],
#  ['Could you get a seat St. Cloud-STL the 28th of Mar', 'booking'],
#  ['Book a seat Cincinnati SIT Sep 18 2025', 'booking'],
#  ['Book seats from Stillwater to Chattanooga for early tomorrow', 'booking'],
#  ['Book seats Mobile to Longview tomorrow afternoon', 'booking'],
#  ['Can you book seats Valdosta - Johnstown next Wednesday', 'booking'],
#  ['Will you book seats Nantucket-Fairbanks next Thu', 'booking'],
#  ['Try booking seats from ENV to Mission tomorrow night', 'booking'],
#  ['Please book the 4th of next month Pittsburgh Roanoke', 'booking'],
#  ['Could you book next month on the 13th Kona to DCA', 'booking'],
#  ['Would you book April 22 LAS - Oakland', 'booking'],
#  ['Book the 14th of May Gustavus-AUS', 'booking'],
#  ['Book Aug 6 2025 Niagara Falls RST', 'booking'],
#  ['Book three days from now from LRD to CEC', 'booking'],
#  ['Book on 7/12 CWA to SCK', 'booking'],
#  ['Book FWA to XNA on 2/19', 'booking'],
#  ['reserve HDN - CLL for 7/1/26', 'booking'],
#  ['reserve IFP-PNS 9-28', 'booking'],
#  ['reserve CIC-OGG 5-14 am', 'booking'],
#  ['reserve MFE-CRP 12-20 a.m.', 'booking'],
#  ['Search RAP-OGG 2-24 early', 'booking'],
#  ['Search for CHS-COU 9-29 morning', 'booking'],
#  ['reserve CPR BDL 4-16-26', 'booking'],
#  ['reserve a Twin Falls to Allentown flight tomorrow', 'booking'],
#  ['reserve a Columbia - Charlotte flight next Tuesday', 'booking'],
#  ['Please reserve a Bethel-Mammoth Lakes flight next Fri', 'booking'],
#  ['Try reserving a San Diego Tallahassee flight the 7th of next month',
#   'booking'],
#  ['reserve a Cold Bay to HOB flight next month on the 25th', 'booking'],
#  ['reserve a PPG - Rapid City flight on May 8', 'booking'],
#  ['reserve a Columbia-AKN flight the 8th of Aug', 'booking'],
#  ['reserve a Cold Bay SNA flight Oct 12 2025', 'booking'],
#  ['Can you reserve a SPI to MLI flight 7/29 after 6:00?', 'booking'],
#  ['Could you reserve a SNA - HLN flight 10/7/25', 'booking'],
#  ['Will you reserve a SYR-FOE flight for 11-13', 'booking'],
#  ['Would you reserve a PIT-GST flight 11-20 pm?', 'booking'],
#  ['reserve a SHV-MBS flight 9-30 pm', 'booking'],
#  ['reserve a SLN-TXK flight 9-15 p.m.', 'booking'],
#  ['reserve a GCC-LCK flight for 8-15 late', 'booking'],
#  ['reserve a EAR-PSG flight 6-13 at night', 'booking'],
#  ['A reservation ECP FCA 3-18-26 please', 'booking'],
#  ['reserve the 27th of next month Sault Ste. Marie Punta Gorda', 'booking'],
#  ['reserve next month on the 26th Aguadilla to BWI', 'booking'],
#  ['reserve August 28 HTS - Salt Lake City', 'booking'],
#  ['What are my chances of flying the 3rd of Apr San Jose-DAY', 'booking'],
#  ['How does Oct 21 2025 Cleveland APN look?', 'booking'],
#  ['reserve two days from now from BLI to EVV', 'booking'],
#  ['reserve on 3/17 RST to ELP', 'booking'],
#  ['reserve PPG to GRI on 7/4', 'booking'],
#  ['Make a reservation YNG to TVC on 10/15', 'booking'],
#  ['Make a reservation CIU MKE 6-27', 'booking'],
#  ['schedule an early flight from Fort Wayne to Lewisburg tomorrow', 'booking'],
#  ['schedule an early flight Reno to Bristol tomorrow evening', 'booking'],
#  ['schedule an early flight Portland - Killeen next Saturday', 'booking'],
#  ['Could you schedule an early flight Raleigh-Nashville next Sun', 'booking'],
#  ['schedule an early flight from EFD to Tokeen tomorrow night', 'booking'],
#  ['schedule a late flight Kahului Nome the 2nd of next month', 'booking'],
#  ['flight Cody to FAI schedule next month on the 1st', 'booking'],
#  ['a late flight scheduling SFB - Colorado Springs February 7 please',
#   'booking'],
#  ['Rhinelander-MIA schedule the 28th of Nov flight', 'booking'],
#  ['Ashland CIC schedule Nov 22 25', 'booking'],
#  ['schedule anything from LAR to HPN three days from now', 'booking'],
#  ['schedule anything SLN to SAT for 10/9', 'booking'],
#  ['schedule anything BDL - CHS on 5/2/26', 'booking'],
#  ['search availability EFD-PUB on 9-19', 'booking'],
#  ['schedule anything IAD EAR for 10-18-25', 'booking'],
#  ['schedule a flight from Great Falls to Williston tomorrow', 'booking'],
#  ['schedule a flight Miami to Gulfport tomorrow evening', 'booking'],
#  ['schedule a flight Hartford - San Diego next Wednesday', 'booking'],
#  ['schedule a flight Joplin-Bristol next Wed', 'booking'],
#  ['schedule a flight from EAR to Louisville tomorrow night', 'booking'],
#  ['schedule a seat Stockton Fayetteville the 16th of next month', 'booking'],
#  ['schedule a seat Omaha to PIH next month on the 24th', 'booking'],
#  ["see what's available LBL - Appleton May 5", 'booking'],
#  ['schedule a seat Grand Island-GRR the 24th of Jun', 'booking'],
#  ['schedule a seat Great Falls FWA Oct 17 25', 'booking'],
#  ['schedule seats from Lubbock to Scottsbluff for early tomorrow', 'booking'],
#  ['schedule seats Hays to Appleton tomorrow afternoon', 'booking'],
#  ['Can you schedule seats Santa Barbara - San Antonio next Monday', 'booking'],
#  ['Will you schedule seats Del Rio-Butte next Sat', 'booking'],
#  ['Try scheduling seats from CAE to Helena tomorrow night', 'booking'],
#  ['Please schedule the 15th of next month Myrtle Beach Ashland', 'booking'],
#  ['Could you schedule next month on the 8th West Yellowstone to GCC',
#   'booking'],
#  ['Would you schedule August 24 OKC - Everett', 'booking'],
#  ['schedule the 6th of Oct Durango-LFT', 'booking'],
#  ['schedule Mar 2 26 Ponce ACV', 'booking'],
#  ['schedule six days from now from DAL to RAP', 'booking'],
#  ['schedule on 11/8 SAV to CGI', 'booking'],
#  ['schedule COU to PSP on 11/3', 'booking'],
#  ['Find an early flight from Atlantic City to Albany tomorrow', 'booking'],
#  ['Find an early flight Kona to Bangor tomorrow evening', 'booking'],
#  ['Find an early flight Laredo - San Angelo next Friday', 'booking'],
#  ['Find an early flight Pellston-Wrangell next Sun', 'booking'],
#  ['Find an early flight from OME to Richmond tomorrow night', 'booking'],
#  ['Find a late flight Bozeman Bozeman the 20th of next month', 'booking'],
#  ['check SWO to MRY next month on the 6th', 'booking'],
#  ['Find a late flight LNK - San Luis Obispo December 30', 'booking'],
#  ['Find a late flight Minneapolis-IAH the 22nd of Nov', 'booking'],
#  ['Find a late flight Gainesville BPT Jun 11 26', 'booking'],
#  ['Find anything from RIW to GPT seven days from now', 'booking'],
#  ['Find anything LWS to CAE for 5/10', 'booking'],
#  ['Find anything GEG - SUX on 12/29/25', 'booking'],
#  ['Find anything RIC-AVP on 11-28', 'booking'],
#  ['Find anything FAI ALW for 3-22-26', 'booking'],
#  ['Find a flight from Longview to Sun Valley tomorrow', 'booking'],
#  ['Find available flights Norfolk to Grand Rapids tomorrow evening',
#   'booking'],
#  ['search available flights Champaign - Akron next Friday', 'booking'],
#  ['Find a flight Ogden-Chicago next Thu', 'booking'],
#  ['Find a flight from LCH to Houston tomorrow night', 'booking'],
#  ['Find a flight Paducah Plattsburgh the 13th of next month', 'booking'],
#  ['Find a flight Juneau to MSP next month on the 24th', 'booking'],
#  ['check EAT - Crescent City September 10', 'booking'],
#  ['Find a flight Plattsburgh-LGA the 18th of Dec', 'booking'],
#  ['Find a flight Little Rock MLB Jul 5 26', 'booking'],
#  ['Find a flight from PAE to GUM ten days from now', 'booking'],
#  ['Find a flight ALS to APN 11/24', 'booking'],
#  ['Can you find a flight GUC - LRD 4/8/26', 'booking'],
#  ['Can you find a flight SMX-BWI 5-13', 'booking'],
#  ['Can you find a flight TYS BWI 2-20-26', 'booking'],
#  ['Can you find from San Luis Obispo to Newport News for early tomorrow',
#   'booking'],
#  ['Check International Falls to Wichita Falls tomorrow afternoon', 'booking'],
#  ['Can you find Watertown - Alamosa next Tuesday', 'booking'],
#  ['Can you find Atlanta-Ketchikan next Wed', 'booking'],
#  ['Can you find from SCE to Manchester tomorrow night', 'booking'],
#  ['Can you find Owensboro Fort Smith the 28th of next month', 'booking'],
#  ['Can you find Roswell to PSC next month on the 7th', 'booking'],
#  ['Find OWB - Wilmington February 7', 'booking'],
#  ['Find King Salmon-BOS the 9th of Nov', 'booking'],
#  ['Find West Yellowstone DCA 8 Mar', 'booking'],
#  ['Find from ACT to OKC one days from now', 'booking'],
#  ['Find BIH to MFR on 4/5', 'booking'],
#  ['Find HHH - EFD for 2/26/26', 'booking'],
#  ['Find CNY-ABR 6-11', 'booking'],
#  ['Find JAC-ENV 2-9 am', 'booking'],
#  ['Try finding COS-PNS 2-22 a.m.', 'booking'],
#  ['Try finding HYS-BOS 12-26 early', 'booking'],
#  ['check for a flight KTN-CIC 5-28 morning', 'booking'],
#  ['Try finding ELP CHS 6-3-26', 'booking'],
#  ['Try finding an available flight tomorrow Binghamton to Cleveland',
#   'booking'],
#  ['Try finding a flight next Tuesday Palm Springs - Atlantic City', 'booking'],
#  ['Try finding a flight next Fri Decatur-Des Moines', 'booking'],
#  ['Try finding a flight the 11th of next month Tucson Moab', 'booking'],
#  ['Try finding a flight next month on the 28th Williston to FAY', 'booking'],
#  ['Try finding a flight on August 14 RSW - Stillwater', 'booking'],
#  ['Try finding a flight the 28th of Dec Belleville-CIU', 'booking'],
#  ['Find a flight 13 May Roanoke USA', 'booking'],
#  ['Find a flight 4/17 after 6:00 RHI to LYH', 'booking'],
#  ['Find a HOU - CMI flight 1/2/26', 'booking'],
#  ['Find a CAK-VEL flight for 6-11', 'booking'],
#  ['Find a MRY-IAD flight 11-6 pm', 'booking'],
#  ['Find a EFD-SHV flight 7-24 pm', 'booking'],
#  ['Find a IMT-GNV flight 2-2 p.m.', 'booking'],
#  ['Please find a RAP-DHN flight for 7-13 late', 'booking'],
#  ['Please find a ONT-ROA flight 6-23 at night', 'booking'],
#  ['What can you find SPS EGE 1-20-26', 'booking'],
#  ['Please find a ITO - MEM trip 9/15/25', 'booking'],
#  ['What can you find ALS-CWA for 2-5', 'booking'],
#  ['Please find a FCA-RHI trip 5-31 pm', 'booking'],
#  ['Please find a LYH-AKN trip 11-6 pm', 'booking'],
#  ['Find a JAX-PBI trip 5-3 p.m.', 'booking'],
#  ['Find a MSY-GCC trip for 11-12 late', 'booking'],
#  ['Find a BWI-SIT trip 4-22 at night', 'booking'],
#  ['Find a DRT FOD trip 8-9-25', 'booking'],
#  ['Find FOE - LSE seats 4/14/26', 'booking'],
#  ['Find ORD-ORH seats for 11-14', 'booking'],
#  ['check seats EGE-ESC 4-27 pm', 'booking'],
#  ['Find OGS-SBN seats 3-11 pm', 'booking'],
#  ['Find PGV-MHT seats 5-2 p.m.', 'booking'],
#  ['Find ALB-BUF seats for 6-2 late', 'booking'],
#  ['what can you find SBN-PIR 2-28 at night?', 'booking'],
#  ['Find VLD SHD seats 9-2-25', 'booking'],
#  ['Find travel from Texarkana to Yakutat for early tomorrow', 'booking'],
#  ['Find travel Springfield to Fayetteville tomorrow afternoon', 'booking'],
#  ['Find travel Bloomington - Carlsbad next Sunday', 'booking'],
#  ['Find availability Colorado Springs-Laredo next Tue', 'booking'],
#  ['Find travel from FAR to Louisville tomorrow night', 'booking'],
#  ['Find travel Philadelphia Bozeman the 22nd of next month', 'booking'],
#  ['Find travel Billings to ISP next month on the 16th', 'booking'],
#  ['Find availability CWA - Bloomington January 20', 'booking'],
#  ['Find travel San Jose-DEN the 24th of Aug', 'booking'],
#  ['Find travel Texarkana SIT 16 Nov', 'booking'],
#  ['Find travel from RDM to MMH six days from now', 'booking'],
#  ['Look for travel from Everett to Dallas for early tomorrow', 'booking'],
#  ['Look for travel Indianapolis to Birmingham tomorrow afternoon', 'booking'],
#  ['Look for travel Ogdensburg - Topeka next Saturday', 'booking'],
#  ['Look for travel Pocatello-Long Beach next Sun', 'booking'],
#  ['Look for travel from RNO to Devils Lake tomorrow night', 'booking'],
#  ['Look for travel Pocatello Peoria the 28th of next month', 'booking'],
#  ['Try looking for travel Knoxville to COS next month on the 8th', 'booking'],
#  ['Try looking for travel LGB - Minneapolis June 28', 'booking'],
#  ['Try looking for travel Harlingen-HIB the 27th of Jan', 'booking'],
#  ['Can I fly Hilton Head FAY on 9 May', 'booking'],
#  ['Try looking for travel from SPN to ACV three days from now', 'booking'],
#  ['Try looking from Islip to Montrose for early tomorrow', 'booking'],
#  ['Try looking for Providence to Bristol tomorrow afternoon', 'booking'],
#  ['Try looking for Sioux Falls - Waterloo next Monday', 'booking'],
#  ['Try looking for Albany-Orlando next Sat', 'booking'],
#  ['Try looking at RIC to Roswell for tomorrow night', 'booking'],
#  ['Look for Harlingen Norfolk the 22nd of next month', 'booking'],
#  ['Look for Longview to APN next month on the 16th', 'booking'],
#  ['Look at PAE - Lake Charles August 26', 'booking'],
#  ['Look up Newport News-ABR the 11th of Aug', 'booking'],
#  ['Look up San Diego CMX 28 Sep', 'booking'],
#  ['Look at MSY to DEC nine days from now', 'booking'],
#  ['Anything from Norfolk to Panama City for early tomorrow?', 'booking'],
#  ['Anything Niagara Falls to Portland tomorrow afternoon?', 'booking'],
#  ['Anything Binghamton - Latrobe next Sunday ?', 'booking'],
#  ['Anything Hagerstown-Austin next Sat ?', 'booking'],
#  ['Anything from SHR to Liberal tomorrow night?', 'booking'],
#  ['Anything Pueblo Palm Springs the 16th of next month?', 'booking'],
#  ['Is it possible to fly Minot to Hobbs next month on the 1st ?', 'booking'],
#  ['Anything JLN - Melbourne December 7 ?', 'booking'],
#  ['Anything Columbia-DEC the 22nd of Feb ?', 'booking'],
#  ['Anything Medford JAC 27 Jul 25 ?', 'booking'],
#  ['Anything from CLD to SHR ten days from now?', 'booking'],
#  ['Is there anything for early tomorrow from Scranton to North Bend ?',
#   'booking'],
#  ['Is there anything tomorrow afternoon Nome to Kearney ?', 'booking'],
#  ['Is there anything next Thursday Dallas - Rhinelander ?', 'booking'],
#  ['Is there anything next Sat Florence-Iron Mountain ?', 'booking'],
#  ['Is there anything tomorrow night from DBQ to Garden City ?', 'booking'],
#  ['Is there anything the 1st of next month Quincy Valdosta ?', 'booking'],
#  ['Is there anything next month on the 26th Champaign to CRW ?', 'booking'],
#  ['Is there anything October 5 LAX - Pullman ?', 'booking'],
#  ['Is there anything the 14th of Apr Montrose-SHR ?', 'booking'],
#  ['Is there anything 15 Sep 25 Grand Junction LAN ?', 'booking'],
#  ['Is there anything four days from now from AZA to PBG ?', 'booking'],
#  ['Are there any flights for early tomorrow from Laramie to Allentown ?',
#   'booking'],
#  ['Are there any flights tomorrow afternoon Daytona Beach to Baltimore ?',
#   'booking'],
#  ['Are there any flights next Thursday Evansville - Sanford ?', 'booking'],
#  ['Are there any flights next Mon Ithaca-Concord ?', 'booking'],
#  ['Are there any flights tomorrow night from BKG to Bellingham ?', 'booking'],
#  ['Are there any flights the 20th of next month Bethel Eugene ?', 'booking'],
#  ['Are there any flights next month on the 5th Prescott to LBL ?', 'booking'],
#  ['Are there any flights February 7 LBE - Carlsbad ?', 'booking'],
#  ['Are there any flights the 17th of Mar New Bern-HSV ?', 'booking'],
#  ['Are there any flights 17 Nov 25 San Diego SWF ?', 'booking'],
#  ['Are there any flights six days from now from SNA to SMX ?', 'booking'],
#  ['any trips for early tomorrow from Wenatchee to Allentown ?', 'booking'],
#  ['any trips tomorrow afternoon Williston to Mobile ?', 'booking'],
#  ['any trips next Saturday Belleville - Monterey ?', 'booking'],
#  ['any trips next Tue Little Rock-Moline ?', 'booking'],
#  ['any flights tomorrow night from AVL to White Plains ?', 'booking'],
#  ['any trips the 15th of next month Devils Lake Lubbock ?', 'booking'],
#  ['any trips next month on the 25th Traverse City to PSG ?', 'booking'],
#  ['any trips September 20 ILG - Wilmington ?', 'booking'],
#  ['any trips the 20th of Aug Montgomery-OGG ?', 'booking'],
#  ['any trips 1 Aug 25 Santa Fe ROC ?', 'booking'],
#  ['any trips six days from now from IYK to DAY ?', 'booking'],
#  ['Do you have any trips next Sun Fayetteville-Minot ?', 'booking'],
#  ['Do you have any trips tomorrow night from MLI to Lincoln ?', 'booking'],
#  ['Do you have any trips the 16th of next month Aspen Petersburg ?',
#   'booking'],
#  ['Do you have any trips next month on the 27th Victoria to PWM ?', 'booking'],
#  ['Do you have any trips November 27 SLN - Charlottesville ?', 'booking'],
#  ['Do you have any trips the 18th of Jul Fort Wayne-DVL ?', 'booking'],
#  ['Do you have any trips 24 Jun 2026 Lexington ABQ ?', 'booking'],
#  ['Do you have any trips six days from now from LRD to HSV ?', 'booking'],
#  ['Do you see any trips next Tue Casper-Appleton ?', 'booking'],
#  ['check United tomorrow night from MBS to Detroit', 'booking'],
#  ['check Delta for the 4th of next month Mosinee Traverse City', 'booking'],
#  ['check American next month on the 5th Evansville to BGR', 'booking'],
#  ['Do you see any trips June 6 PIR - Reno ?', 'booking'],
#  ['Do you see any trips the 28th of Feb Portland-MVY ?', 'booking'],
#  ['Do you see any trips 12 Aug 2025 Rochester RDU ?', 'booking'],
#  ['Do you see any trips two days from now from SBN to LFT ?', 'booking'],
#  ['did you see anything next Tue Amarillo-Sault Ste. Marie ?', 'booking'],
#  ['did you see anything tomorrow night from SMF to Albany ?', 'booking'],
#  ['did you see anything the 15th of next month Nantucket Sanford ?',
#   'booking'],
#  ['did you see anything next month on the 2nd Liberal to MCI ?', 'booking'],
#  ['did you see anything October 17 MSY - Fayetteville ?', 'booking'],
#  ['did you see anything the 19th of Apr Nantucket-EAU ?', 'booking'],
#  ['did you see anything 7 May Salina EYW ?', 'booking'],
#  ['did you see anything nine days from now from MKG to EVV ?', 'booking'],
#  ['did you find anything tomorrow night from AMA to San Juan ?', 'booking'],
#  ['did you find anything the 10th of next month Jacksonville Williston ?',
#   'booking'],
#  ['did you find anything next month on the 5th Riverton to PUB ?', 'booking'],
#  ['check February 16 FWA - Helena ?', 'booking'],
#  ['did you find anything the 10th of Jul Marquette-MSN ?', 'booking'],
#  ['did you find anything May 24 2026 Honolulu UIN ?', 'booking'],
#  ['did you find anything six days from now from HHH to SCK ?', 'booking'],
#  ['rebook G4 9439 departing tomorrow', 'booking'],
#  ['rebook HA 91 for next Friday', 'booking'],
#  ['rebook MQ 1324 for 11-23', 'booking'],
#  ['Reserve NK 9767 for Wednesday', 'booking'],
#  ['Reserve OH 164 for 10 Sep', 'booking'],
#  ['Reserve OO 4224 for Nov 22', 'booking'],
#  ['Schedule UA 5425 for late tomorrow', 'booking'],
#  ['Schedule WN 1417 for early morning tomorrow', 'booking'],
#  ['Schedule YX 6962 for tomorrow night', 'booking'],
#  ['See if I can fly out tomorrow on QX 9590', 'booking'],
#  ['See if I can fly out tomorrow on YV 2277', 'booking'],
#  ['Check if I can fly back next week on EV 9522', 'booking'],
#  ['Check if I can fly back next week on VX 2575', 'booking'],
#  ['Can I fly in seven days from now on US 5145', 'booking'],
#  ['Can I fly in eight days from now on FL 4467', 'booking'],
#  ['rebook Endeavor 8305 arriving tomorrow', 'booking'],
#  ['rebook American 846 for next Saturday', 'booking'],
#  ['rebook Alaska 2797 for 11-20', 'booking'],
#  ['Reserve JetBlue 7779 for Thursday', 'booking'],
#  ['Reserve Delta 8978 for 2 Nov', 'booking'],
#  ['Reserve Frontier 2017 for Jun 5', 'booking'],
#  ['Schedule Allegiant 9960 for late tomorrow', 'booking'],
#  ['Schedule Hawaiian 7671 for early morning tomorrow', 'booking'],
#  ['Schedule American Eagle 4630 for tomorrow night', 'booking'],
#  ['See if I can fly out tomorrow on Spirit 9088', 'booking'],
#  ['See if I can fly out tomorrow on PSA 9866', 'booking'],
#  ['Check if I can fly back next week on SkyWest 8144', 'booking'],
#  ['Check if I can fly back next week on United 1054', 'booking'],
#  ['Can I fly in two days from now on Southwest 7450', 'booking'],
#  ['Can I fly in two days from now on Republic 581', 'booking'],
#  ['rebook QX TKI-MSY for tomorrow', 'booking'],
#  ['rebook YV SAN-WRG for next Tuesday', 'booking'],
#  ['rebook EV CWA-EAT for 2-21', 'booking'],
#  ['Reserve VX LBE-LBL for Sunday', 'booking'],
#  ['Reserve US MCN-ISP for 17 Dec', 'booking'],
#  ['Reserve FL LGB-IAH for April 1', 'booking'],
#  ['Schedule 9E DSM-ABQ for late tomorrow', 'booking'],
#  ['Schedule AA PHF-STT for early tomorrow morning', 'booking'],
#  ['Schedule AS RIC-INL for tomorrow night', 'booking'],
#  ['See if I can fly out tomorrow on B6 ROA-DTW', 'booking'],
#  ['See if I can fly out tomorrow on DL OME-GRR', 'booking'],
#  ['See if I can fly out tomorrow MKE-XWA on F9', 'booking'],
#  ['Check if I can fly back next week on G4 PAH-BIH', 'booking'],
#  ['Check if I can fly back next week on HA FOE-CID', 'booking'],
#  ['Check if I can fly back next week SDF-MGM on MQ', 'booking'],
#  ['Can I fly in two days from now on NK BMI-CDV', 'booking'],
#  ['Can I fly in one days from now on OH CVG-GCK', 'booking'],
#  ['Can I fly in five days from now LBB-PIB on OO', 'booking'],
#  ['rebook United IMT-CID for tomorrow', 'booking'],
#  ['rebook Southwest EVV-SMF for next Saturday', 'booking'],
#  ['rebook Republic GTF-SCE for 2-5', 'booking'],
#  ['Reserve Horizon ABY-BJI for Friday', 'booking'],
#  ['Reserve Mesa BWI-BKG for 9 Feb', 'booking'],
#  ['Reserve ExpressJet FLG-DRO for September 29', 'booking'],
#  ['Schedule Virgin PAE-TKI for late tomorrow', 'booking'],
#  ['Schedule US SEA-SJC for early tomorrow morning', 'booking'],
#  ['Schedule AirTran BFF-PSE for tomorrow night', 'booking'],
#  ['See if I can fly out tomorrow on Endeavor SDF-CMX', 'booking'],
#  ['See if I can fly out tomorrow on American JAN-MLU', 'booking'],
#  ['See if I can fly out tomorrow BLV-STL on Alaska', 'booking'],
#  ['Check if I can fly home next week on JetBlue VEL-ALS', 'booking'],
#  ['Check if I can fly out next week on Delta LFT-LAR', 'booking'],
#  ['Check if I can fly back next week CAE-GST on Frontier', 'booking'],
#  ['Can I fly in five days from now on Allegiant ABR-LBE', 'booking'],
#  ['Can I fly in ten days from now on Hawaiian ONT-MFR', 'booking'],
#  ['Can I fly in nine days from now PAE-MQT on American Eagle', 'booking'],
#  ['Book Spirit Cody-Alexandria for tomorrow', 'booking'],
#  ['Book PSA Pellston-Pittsburgh for next Monday', 'booking'],
#  ['Book SkyWest Chicago-State College for 10-30', 'booking'],
#  ['Reserve United Newark-Louisville for Monday', 'booking'],
#  ['Reserve Southwest Manchester-Fort Wayne for 19 Aug', 'booking'],
#  ['Reserve Republic San Diego-Hibbing for October 20', 'booking'],
#  ['Schedule Horizon Panama City-Jackson for late tomorrow', 'booking'],
#  ['Schedule Mesa Kotzebue-King Salmon for early tomorrow morning', 'booking'],
#  ['Schedule ExpressJet Dallas-Santa Fe for tomorrow night', 'booking'],
#  ['See if I can fly out tomorrow on Virgin Duluth-Sitka', 'booking'],
#  ['See if I can fly out tomorrow on US Sitka-Cleveland', 'booking'],
#  ['See if I can fly out tomorrow Atlanta-Richmond on AirTran', 'booking'],
#  ['Check if I can fly back next week on Endeavor Moab-West Palm Beach',
#   'booking'],
#  ['Check if I can fly back next week on American Spokane-Cheyenne', 'booking'],
#  ['Check if I can fly home next week Greenville-Huntsville on Alaska',
#   'booking'],
#  ['Can I fly in five days from now on JetBlue Milwaukee-Hagerstown',
#   'booking'],
#  ['Can I fly in four days from now on Delta Bethel-Rochester', 'booking'],
#  ['Can I fly home two days from now from Mobile to Sheridan on Frontier',
#   'booking'],
#  ['create a PNR for 1-23 HYS-MSP', 'booking'],
#  ['book a pnr Erie-Rochester for next Tuesday afternoon', 'booking'],
#  ['reserve GCK to LGA on 9 Mar and send me the record locator', 'booking'],
#  ['create a record locator MEI SPS 9/16', 'booking'],
#  ['book STL IMT 10-3 2025 and give me the PNR', 'booking'],
#  ['i need a pnr for Vernal San Luis Obispo Sep 8th', 'booking']]

# %%
# Shuffle the list a few times
import random
random.shuffle(altered_data)
random.shuffle(altered_data)
random.shuffle(altered_data)

# %%
# Add the header labels
altered_data.insert(0, ['query','intent'])
altered_data, len(altered_data)
# Out:
# ([['query', 'intent'],
#   ['Find ORD-ORH seats for 11-14', 'booking'],
#   ['Anything Hagerstown-Austin next Sat ?', 'booking'],
#   ['Check if I can fly back next week on HA FOE-CID', 'booking'],
#   ['rebook Alaska 2797 for 11-20', 'booking'],
#   ['Find a flight from Longview to Sun Valley tomorrow', 'booking'],
#   ['See if I can fly out tomorrow on PSA 9866', 'booking'],
#   ['Anything Columbia-DEC the 22nd of Feb ?', 'booking'],
#   ['Try finding a flight the 28th of Dec Belleville-CIU', 'booking'],
#   ['Will you schedule seats Del Rio-Butte next Sat', 'booking'],
#   ['Find travel San Jose-DEN the 24th of Aug', 'booking'],
#   ['Try finding an available flight tomorrow Binghamton to Cleveland',
#    'booking'],
#   ['Is it possible to fly Minot to Hobbs next month on the 1st ?', 'booking'],
#   ['Schedule AS RIC-INL for tomorrow night', 'booking'],
#   ['did you find anything six days from now from HHH to SCK ?', 'booking'],
#   ['Do you see any trips two days from now from SBN to LFT ?', 'booking'],
#   ['Try looking for travel from SPN to ACV three days from now', 'booking'],
#   ['See if I can fly out tomorrow on DL OME-GRR', 'booking'],
#   ['Book an early flight Gulfport to El Paso tomorrow evening', 'booking'],
#   ['Will you book seats Nantucket-Fairbanks next Thu', 'booking'],
#   ['Find a late flight LNK - San Luis Obispo December 30', 'booking'],
#   ['Can you find from San Luis Obispo to Newport News for early tomorrow',
#    'booking'],
#   ['search available flights Champaign - Akron next Friday', 'booking'],
#   ['Check if I can fly home next week Greenville-Huntsville on Alaska',
#    'booking'],
#   ['See if I can fly out tomorrow on B6 ROA-DTW', 'booking'],
#   ['Find a flight Juneau to MSP next month on the 24th', 'booking'],
#   ['Look for Longview to APN next month on the 16th', 'booking'],
#   ['any trips 1 Aug 25 Santa Fe ROC ?', 'booking'],
#   ['schedule a flight Hartford - San Diego next Wednesday', 'booking'],
#   ['Check if I can fly home next week on JetBlue VEL-ALS', 'booking'],
#   ['Can you find Owensboro Fort Smith the 28th of next month', 'booking'],
#   ['Book FWA to XNA on 2/19', 'booking'],
#   ['a late flight scheduling SFB - Colorado Springs February 7 please',
#    'booking'],
#   ['Find available flights Norfolk to Grand Rapids tomorrow evening',
#    'booking'],
#   ['Find an early flight Kona to Bangor tomorrow evening', 'booking'],
#   ['Look for travel Pocatello-Long Beach next Sun', 'booking'],
#   ['Can I fly in ten days from now on Hawaiian ONT-MFR', 'booking'],
#   ['Can you find Roswell to PSC next month on the 7th', 'booking'],
#   ['Could you get a seat St. Cloud-STL the 28th of Mar', 'booking'],
#   ['Schedule Mesa Kotzebue-King Salmon for early tomorrow morning', 'booking'],
#   ['Try looking from Islip to Montrose for early tomorrow', 'booking'],
#   ['Find HHH - EFD for 2/26/26', 'booking'],
#   ['Find CNY-ABR 6-11', 'booking'],
#   ['See if I can fly out tomorrow Atlanta-Richmond on AirTran', 'booking'],
#   ['Anything from CLD to SHR ten days from now?', 'booking'],
#   ['Are there any flights tomorrow night from BKG to Bellingham ?', 'booking'],
#   ['rebook Southwest EVV-SMF for next Saturday', 'booking'],
#   ['Schedule WN 1417 for early morning tomorrow', 'booking'],
#   ['Are there any flights next Mon Ithaca-Concord ?', 'booking'],
#   ['did you see anything October 17 MSY - Fayetteville ?', 'booking'],
#   ['Book anything RDD - SPN on 7/27/25', 'booking'],
#   ['check SWO to MRY next month on the 6th', 'booking'],
#   ['Search for CHS-COU 9-29 morning', 'booking'],
#   ['did you see anything nine days from now from MKG to EVV ?', 'booking'],
#   ['Reserve Frontier 2017 for Jun 5', 'booking'],
#   ['Look at MSY to DEC nine days from now', 'booking'],
#   ['Try looking for Albany-Orlando next Sat', 'booking'],
#   ['did you see anything tomorrow night from SMF to Albany ?', 'booking'],
#   ['A reservation ECP FCA 3-18-26 please', 'booking'],
#   ['Find FOE - LSE seats 4/14/26', 'booking'],
#   ['Look for travel Pocatello Peoria the 28th of next month', 'booking'],
#   ['Book a seat Charleston to AGS next month on the 9th', 'booking'],
#   ['Find from ACT to OKC one days from now', 'booking'],
#   ['Reserve OH 164 for 10 Sep', 'booking'],
#   ['Do you see any trips the 28th of Feb Portland-MVY ?', 'booking'],
#   ['Schedule Allegiant 9960 for late tomorrow', 'booking'],
#   ['Is there anything 15 Sep 25 Grand Junction LAN ?', 'booking'],
#   ['Are there any flights next month on the 5th Prescott to LBL ?', 'booking'],
#   ['Do you have any trips next Sun Fayetteville-Minot ?', 'booking'],
#   ['Check if I can fly back next week on Endeavor Moab-West Palm Beach',
#    'booking'],
#   ['Are there any flights six days from now from SNA to SMX ?', 'booking'],
#   ['Do you have any trips next month on the 27th Victoria to PWM ?',
#    'booking'],
#   ['Reserve VX LBE-LBL for Sunday', 'booking'],
#   ['Find travel Springfield to Fayetteville tomorrow afternoon', 'booking'],
#   ['reserve the 27th of next month Sault Ste. Marie Punta Gorda', 'booking'],
#   ['Book a flight Austin to Ogdensburg tomorrow evening', 'booking'],
#   ['Check if I can fly back next week on VX 2575', 'booking'],
#   ['Book seats from Stillwater to Chattanooga for early tomorrow', 'booking'],
#   ['reserve HDN - CLL for 7/1/26', 'booking'],
#   ['Can you find a flight GUC - LRD 4/8/26', 'booking'],
#   ['Book an early flight from Fort Smith to Cody tomorrow', 'booking'],
#   ['Would you reserve a PIT-GST flight 11-20 pm?', 'booking'],
#   ['What can you find SPS EGE 1-20-26', 'booking'],
#   ['Could you schedule next month on the 8th West Yellowstone to GCC',
#    'booking'],
#   ['Schedule US SEA-SJC for early tomorrow morning', 'booking'],
#   ['Can you reserve a SPI to MLI flight 7/29 after 6:00?', 'booking'],
#   ['What are my chances of flying the 3rd of Apr San Jose-DAY', 'booking'],
#   ['Find travel from FAR to Louisville tomorrow night', 'booking'],
#   ['Schedule AirTran BFF-PSE for tomorrow night', 'booking'],
#   ['Find a flight from LCH to Houston tomorrow night', 'booking'],
#   ['any trips the 15th of next month Devils Lake Lubbock ?', 'booking'],
#   ['reserve a Columbia-AKN flight the 8th of Aug', 'booking'],
#   ['Can you find Atlanta-Ketchikan next Wed', 'booking'],
#   ['Look for Harlingen Norfolk the 22nd of next month', 'booking'],
#   ['schedule an early flight Portland - Killeen next Saturday', 'booking'],
#   ['Find a DRT FOD trip 8-9-25', 'booking'],
#   ['Please find a FCA-RHI trip 5-31 pm', 'booking'],
#   ['did you see anything 7 May Salina EYW ?', 'booking'],
#   ['Is there anything for early tomorrow from Scranton to North Bend ?',
#    'booking'],
#   ['check February 16 FWA - Helena ?', 'booking'],
#   ['Try finding ELP CHS 6-3-26', 'booking'],
#   ['flight Cody to FAI schedule next month on the 1st', 'booking'],
#   ['Please find a LYH-AKN trip 11-6 pm', 'booking'],
#   ['did you see anything next Tue Amarillo-Sault Ste. Marie ?', 'booking'],
#   ['Schedule Virgin PAE-TKI for late tomorrow', 'booking'],
#   ['Book the 14th of May Gustavus-AUS', 'booking'],
#   ['schedule anything SLN to SAT for 10/9', 'booking'],
#   ['Find a flight ALS to APN 11/24', 'booking'],
#   ['any trips the 20th of Aug Montgomery-OGG ?', 'booking'],
#   ['query', 'intent'],
#   ['reserve PPG to GRI on 7/4', 'booking'],
#   ['Is there anything the 1st of next month Quincy Valdosta ?', 'booking'],
#   ['Is there anything October 5 LAX - Pullman ?', 'booking'],
#   ['Find a MSY-GCC trip for 11-12 late', 'booking'],
#   ['Find a flight Paducah Plattsburgh the 13th of next month', 'booking'],
#   ['reserve two days from now from BLI to EVV', 'booking'],
#   ['schedule a flight from Great Falls to Williston tomorrow', 'booking'],
#   ['Try looking for travel Knoxville to COS next month on the 8th', 'booking'],
#   ['Reserve Horizon ABY-BJI for Friday', 'booking'],
#   ['Book seats Mobile to Longview tomorrow afternoon', 'booking'],
#   ['Try looking at RIC to Roswell for tomorrow night', 'booking'],
#   ['any trips September 20 ILG - Wilmington ?', 'booking'],
#   ['Do you have any trips the 16th of next month Aspen Petersburg ?',
#    'booking'],
#   ['Find a flight Ogden-Chicago next Thu', 'booking'],
#   ['Find anything LWS to CAE for 5/10', 'booking'],
#   ['Find travel from Texarkana to Yakutat for early tomorrow', 'booking'],
#   ['reserve a Twin Falls to Allentown flight tomorrow', 'booking'],
#   ['Reserve Mesa BWI-BKG for 9 Feb', 'booking'],
#   ['reserve a PPG - Rapid City flight on May 8', 'booking'],
#   ['Book a seat Lafayette Charleston the 25th of next month', 'booking'],
#   ['reserve GCK to LGA on 9 Mar and send me the record locator', 'booking'],
#   ['Are there any flights tomorrow afternoon Daytona Beach to Baltimore ?',
#    'booking'],
#   ['Are there any flights the 17th of Mar New Bern-HSV ?', 'booking'],
#   ['schedule anything from LAR to HPN three days from now', 'booking'],
#   ['check for a flight KTN-CIC 5-28 morning', 'booking'],
#   ['Schedule American Eagle 4630 for tomorrow night', 'booking'],
#   ['Book Aug 6 2025 Niagara Falls RST', 'booking'],
#   ['any trips six days from now from IYK to DAY ?', 'booking'],
#   ['did you find anything the 10th of next month Jacksonville Williston ?',
#    'booking'],
#   ['Schedule 9E DSM-ABQ for late tomorrow', 'booking'],
#   ['Reserve United Newark-Louisville for Monday', 'booking'],
#   ['Is there anything next month on the 26th Champaign to CRW ?', 'booking'],
#   ['Check if I can fly back next week on SkyWest 8144', 'booking'],
#   ['Try looking for travel Harlingen-HIB the 27th of Jan', 'booking'],
#   ['Check if I can fly out next week on Delta LFT-LAR', 'booking'],
#   ['did you see anything the 19th of Apr Nantucket-EAU ?', 'booking'],
#   ['Look for travel Indianapolis to Birmingham tomorrow afternoon', 'booking'],
#   ['any trips for early tomorrow from Wenatchee to Allentown ?', 'booking'],
#   ['Find a BWI-SIT trip 4-22 at night', 'booking'],
#   ['rebook Endeavor 8305 arriving tomorrow', 'booking'],
#   ['Schedule AA PHF-STT for early tomorrow morning', 'booking'],
#   ['schedule an early flight Reno to Bristol tomorrow evening', 'booking'],
#   ['Try finding a flight the 11th of next month Tucson Moab', 'booking'],
#   ['reserve a EAR-PSG flight 6-13 at night', 'booking'],
#   ['any flights tomorrow night from AVL to White Plains ?', 'booking'],
#   ['check United tomorrow night from MBS to Detroit', 'booking'],
#   ['Are there any flights 17 Nov 25 San Diego SWF ?', 'booking'],
#   ['reserve CIC-OGG 5-14 am', 'booking'],
#   ['Anything Niagara Falls to Portland tomorrow afternoon?', 'booking'],
#   ['reserve IFP-PNS 9-28', 'booking'],
#   ['Are there any flights the 20th of next month Bethel Eugene ?', 'booking'],
#   ['Try finding COS-PNS 2-22 a.m.', 'booking'],
#   ['Are there any flights next Thursday Evansville - Sanford ?', 'booking'],
#   ['Do you see any trips June 6 PIR - Reno ?', 'booking'],
#   ['Look for travel from Everett to Dallas for early tomorrow', 'booking'],
#   ['Try reserving a San Diego Tallahassee flight the 7th of next month',
#    'booking'],
#   ['schedule a flight Miami to Gulfport tomorrow evening', 'booking'],
#   ['create a record locator MEI SPS 9/16', 'booking'],
#   ['Look up San Diego CMX 28 Sep', 'booking'],
#   ['Anything JLN - Melbourne December 7 ?', 'booking'],
#   ['Find travel from RDM to MMH six days from now', 'booking'],
#   ['Try finding a flight on August 14 RSW - Stillwater', 'booking'],
#   ['Find BIH to MFR on 4/5', 'booking'],
#   ['Ashland CIC schedule Nov 22 25', 'booking'],
#   ['any trips next Saturday Belleville - Monterey ?', 'booking'],
#   ['schedule a seat Stockton Fayetteville the 16th of next month', 'booking'],
#   ['Try finding a flight next month on the 28th Williston to FAY', 'booking'],
#   ['Find an early flight from OME to Richmond tomorrow night', 'booking'],
#   ['Please find a ITO - MEM trip 9/15/25', 'booking'],
#   ['Book three days from now from LRD to CEC', 'booking'],
#   ['Do you have any trips six days from now from LRD to HSV ?', 'booking'],
#   ['reserve MFE-CRP 12-20 a.m.', 'booking'],
#   ['reserve a Cold Bay SNA flight Oct 12 2025', 'booking'],
#   ['reserve on 3/17 RST to ELP', 'booking'],
#   ['Can you find a flight SMX-BWI 5-13', 'booking'],
#   ['schedule six days from now from DAL to RAP', 'booking'],
#   ['Find a flight 13 May Roanoke USA', 'booking'],
#   ['Can I fly in five days from now on JetBlue Milwaukee-Hagerstown',
#    'booking'],
#   ['schedule a seat Grand Island-GRR the 24th of Jun', 'booking'],
#   ['reserve a Columbia - Charlotte flight next Tuesday', 'booking'],
#   ['Reserve Southwest Manchester-Fort Wayne for 19 Aug', 'booking'],
#   ['reserve August 28 HTS - Salt Lake City', 'booking'],
#   ['Find availability Colorado Springs-Laredo next Tue', 'booking'],
#   ['schedule an early flight from Fort Wayne to Lewisburg tomorrow',
#    'booking'],
#   ['check American next month on the 5th Evansville to BGR', 'booking'],
#   ['Please find a RAP-DHN flight for 7-13 late', 'booking'],
#   ['Try looking for Providence to Bristol tomorrow afternoon', 'booking'],
#   ['Book a seat Cincinnati SIT Sep 18 2025', 'booking'],
#   ['reserve a Cold Bay to HOB flight next month on the 25th', 'booking'],
#   ['Find travel Philadelphia Bozeman the 22nd of next month', 'booking'],
#   ['any trips next Tue Little Rock-Moline ?', 'booking'],
#   ['Book SkyWest Chicago-State College for 10-30', 'booking'],
#   ['schedule a late flight Kahului Nome the 2nd of next month', 'booking'],
#   ['Reserve ExpressJet FLG-DRO for September 29', 'booking'],
#   ['Find a flight Little Rock MLB Jul 5 26', 'booking'],
#   ['Find VLD SHD seats 9-2-25', 'booking'],
#   ['rebook MQ 1324 for 11-23', 'booking'],
#   ['search availability EFD-PUB on 9-19', 'booking'],
#   ['Find OWB - Wilmington February 7', 'booking'],
#   ['Check if I can fly back next week CAE-GST on Frontier', 'booking'],
#   ['Anything Pueblo Palm Springs the 16th of next month?', 'booking'],
#   ['did you find anything the 10th of Jul Marquette-MSN ?', 'booking'],
#   ['Reserve Delta 8978 for 2 Nov', 'booking'],
#   ['any trips tomorrow afternoon Williston to Mobile ?', 'booking'],
#   ['Book a flight from Albany to Jamestown tomorrow', 'booking'],
#   ['Book an early flight from CLD to Quincy tomorrow night', 'booking'],
#   ['Try finding HYS-BOS 12-26 early', 'booking'],
#   ['Find West Yellowstone DCA 8 Mar', 'booking'],
#   ['Find anything RIC-AVP on 11-28', 'booking'],
#   ['rebook American 846 for next Saturday', 'booking'],
#   ['did you find anything May 24 2026 Honolulu UIN ?', 'booking'],
#   ['Make a reservation YNG to TVC on 10/15', 'booking'],
#   ['Please reserve a Bethel-Mammoth Lakes flight next Fri', 'booking'],
#   ['Look at PAE - Lake Charles August 26', 'booking'],
#   ['Find availability CWA - Bloomington January 20', 'booking'],
#   ['Try scheduling seats from CAE to Helena tomorrow night', 'booking'],
#   ['Would you schedule August 24 OKC - Everett', 'booking'],
#   ['See if I can fly out tomorrow on Spirit 9088', 'booking'],
#   ['Find travel Texarkana SIT 16 Nov', 'booking'],
#   ['Find a late flight Minneapolis-IAH the 22nd of Nov', 'booking'],
#   ['Find anything GEG - SUX on 12/29/25', 'booking'],
#   ['Schedule ExpressJet Dallas-Santa Fe for tomorrow night', 'booking'],
#   ['Can I fly in nine days from now PAE-MQT on American Eagle', 'booking'],
#   ['schedule COU to PSP on 11/3', 'booking'],
#   ['Can you find Watertown - Alamosa next Tuesday', 'booking'],
#   ['Can I fly home two days from now from Mobile to Sheridan on Frontier',
#    'booking'],
#   ['Can you schedule seats Santa Barbara - San Antonio next Monday',
#    'booking'],
#   ['See if I can fly out tomorrow MKE-XWA on F9', 'booking'],
#   ['Check if I can fly back next week SDF-MGM on MQ', 'booking'],
#   ['See if I can fly out tomorrow BLV-STL on Alaska', 'booking'],
#   ['Can I fly in five days from now LBB-PIB on OO', 'booking'],
#   ['Find ALB-BUF seats for 6-2 late', 'booking'],
#   ['See if I can fly out tomorrow on YV 2277', 'booking'],
#   ['Please find a ONT-ROA flight 6-23 at night', 'booking'],
#   ['Can I fly in two days from now on Southwest 7450', 'booking'],
#   ['Find a flight Plattsburgh-LGA the 18th of Dec', 'booking'],
#   ['Book on 7/12 CWA to SCK', 'booking'],
#   ['Can you find from SCE to Manchester tomorrow night', 'booking'],
#   ['Search RAP-OGG 2-24 early', 'booking'],
#   ['Book PSA Pellston-Pittsburgh for next Monday', 'booking'],
#   ['schedule anything BDL - CHS on 5/2/26', 'booking'],
#   ['check Delta for the 4th of next month Mosinee Traverse City', 'booking'],
#   ['schedule a seat Great Falls FWA Oct 17 25', 'booking'],
#   ['Do you have any trips tomorrow night from MLI to Lincoln ?', 'booking'],
#   ['Find a late flight Gainesville BPT Jun 11 26', 'booking'],
#   ['schedule seats Hays to Appleton tomorrow afternoon', 'booking'],
#   ['Book anything ELP HOB for 7-16-25', 'booking'],
#   ['Is there anything four days from now from AZA to PBG ?', 'booking'],
#   ['check seats EGE-ESC 4-27 pm', 'booking'],
#   ['Reserve Republic San Diego-Hibbing for October 20', 'booking'],
#   ['reserve a SLN-TXK flight 9-15 p.m.', 'booking'],
#   ['did you find anything next month on the 5th Riverton to PUB ?', 'booking'],
#   ['schedule the 6th of Oct Durango-LFT', 'booking'],
#   ['rebook United IMT-CID for tomorrow', 'booking'],
#   ['Could you get me a flight from BTV to Raleigh tomorrow night', 'booking'],
#   ['Is there anything tomorrow afternoon Nome to Kearney ?', 'booking'],
#   ['Do you have any trips 24 Jun 2026 Lexington ABQ ?', 'booking'],
#   ['Find a MRY-IAD flight 11-6 pm', 'booking'],
#   ['Try finding a flight next Fri Decatur-Des Moines', 'booking'],
#   ['reserve next month on the 26th Aguadilla to BWI', 'booking'],
#   ['Are there any flights for early tomorrow from Laramie to Allentown ?',
#    'booking'],
#   ['Is there anything next Thursday Dallas - Rhinelander ?', 'booking'],
#   ['Can I fly Hilton Head FAY on 9 May', 'booking'],
#   ['rebook Republic GTF-SCE for 2-5', 'booking'],
#   ['Trenton BLI book Jul 10 2025', 'booking'],
#   ['schedule an early flight from EFD to Tokeen tomorrow night', 'booking'],
#   ['Is there anything the 14th of Apr Montrose-SHR ?', 'booking'],
#   ['Find a JAX-PBI trip 5-3 p.m.', 'booking'],
#   ['Find a EFD-SHV flight 7-24 pm', 'booking'],
#   ['schedule Mar 2 26 Ponce ACV', 'booking'],
#   ['Get two seats AZO - Burlington September 21', 'booking'],
#   ['Check if I can fly back next week on EV 9522', 'booking'],
#   ['Look for travel from RNO to Devils Lake tomorrow night', 'booking'],
#   ['Is there anything next Sat Florence-Iron Mountain ?', 'booking'],
#   ['Reserve US MCN-ISP for 17 Dec', 'booking'],
#   ['Get a flight Scottsbluff-Hibbing next Thu', 'booking'],
#   ['Schedule UA 5425 for late tomorrow', 'booking'],
#   ['Will you reserve a SYR-FOE flight for 11-13', 'booking'],
#   ['schedule a flight from EAR to Louisville tomorrow night', 'booking'],
#   ['Book Spirit Cody-Alexandria for tomorrow', 'booking'],
#   ['See if I can fly out tomorrow on US Sitka-Cleveland', 'booking'],
#   ['rebook QX TKI-MSY for tomorrow', 'booking'],
#   ['Find anything FAI ALW for 3-22-26', 'booking'],
#   ['Reserve NK 9767 for Wednesday', 'booking'],
#   ['Try looking for travel LGB - Minneapolis June 28', 'booking'],
#   ['Book an early flight Pago Pago - Mobile next Tuesday', 'booking'],
#   ['Check International Falls to Wichita Falls tomorrow afternoon', 'booking'],
#   ['Please book the 4th of next month Pittsburgh Roanoke', 'booking'],
#   ['Please schedule the 15th of next month Myrtle Beach Ashland', 'booking'],
#   ['Reserve FL LGB-IAH for April 1', 'booking'],
#   ['Can I fly in two days from now on Republic 581', 'booking'],
#   ['Try booking seats from ENV to Mission tomorrow night', 'booking'],
#   ['Can I fly in four days from now on Delta Bethel-Rochester', 'booking'],
#   ['See if I can fly out tomorrow on American JAN-MLU', 'booking'],
#   ['See if I can fly out tomorrow on Virgin Duluth-Sitka', 'booking'],
#   ['Find an early flight Laredo - San Angelo next Friday', 'booking'],
#   ['Find a flight 4/17 after 6:00 RHI to LYH', 'booking'],
#   ['Schedule Hawaiian 7671 for early morning tomorrow', 'booking'],
#   ['flight Fayetteville to FSM book next month on the 19th', 'booking'],
#   ['Reserve OO 4224 for Nov 22', 'booking'],
#   ['Can I fly in eight days from now on FL 4467', 'booking'],
#   ['Find travel Bloomington - Carlsbad next Sunday', 'booking'],
#   ['Find PGV-MHT seats 5-2 p.m.', 'booking'],
#   ['Can you book seats Valdosta - Johnstown next Wednesday', 'booking'],
#   ['Find a IMT-GNV flight 2-2 p.m.', 'booking'],
#   ['i need a pnr for Vernal San Luis Obispo Sep 8th', 'booking'],
#   ['reserve a GCC-LCK flight for 8-15 late', 'booking'],
#   ['what can you find SBN-PIR 2-28 at night?', 'booking'],
#   ['reserve a SHV-MBS flight 9-30 pm', 'booking'],
#   ['Look up Newport News-ABR the 11th of Aug', 'booking'],
#   ["see what's available LBL - Appleton May 5", 'booking'],
#   ['Schedule YX 6962 for tomorrow night', 'booking'],
#   ['Do you have any trips the 18th of Jul Fort Wayne-DVL ?', 'booking'],
#   ['Can I fly in seven days from now on US 5145', 'booking'],
#   ['book a pnr Erie-Rochester for next Tuesday afternoon', 'booking'],
#   ['Anything Binghamton - Latrobe next Sunday ?', 'booking'],
#   ['schedule a flight Joplin-Bristol next Wed', 'booking'],
#   ['Is there anything tomorrow night from DBQ to Garden City ?', 'booking'],
#   ['rebook HA 91 for next Friday', 'booking'],
#   ['schedule on 11/8 SAV to CGI', 'booking'],
#   ['Are there any flights February 7 LBE - Carlsbad ?', 'booking'],
#   ['schedule a seat Omaha to PIH next month on the 24th', 'booking'],
#   ['Find King Salmon-BOS the 9th of Nov', 'booking'],
#   ['Can I fly in five days from now on Allegiant ABR-LBE', 'booking'],
#   ['schedule anything IAD EAR for 10-18-25', 'booking'],
#   ['See if I can fly out tomorrow on QX 9590', 'booking'],
#   ['rebook YV SAN-WRG for next Tuesday', 'booking'],
#   ['Schedule Horizon Panama City-Jackson for late tomorrow', 'booking'],
#   ['Find a CAK-VEL flight for 6-11', 'booking'],
#   ['Find JAC-ENV 2-9 am', 'booking'],
#   ['Find anything from RIW to GPT seven days from now', 'booking'],
#   ['Find travel Billings to ISP next month on the 16th', 'booking'],
#   ['Book an early flight Fresno-Long Beach next Thu', 'booking'],
#   ['See if I can fly out tomorrow on Endeavor SDF-CMX', 'booking'],
#   ['Do you see any trips 12 Aug 2025 Rochester RDU ?', 'booking'],
#   ['Reserve JetBlue 7779 for Thursday', 'booking'],
#   ['Find a flight from PAE to GUM ten days from now', 'booking'],
#   ['did you see anything next month on the 2nd Liberal to MCI ?', 'booking'],
#   ['Check if I can fly back next week on American Spokane-Cheyenne',
#    'booking'],
#   ['Book a flight Gustavus - Columbus next Tuesday', 'booking'],
#   ['Find a HOU - CMI flight 1/2/26', 'booking'],
#   ['Can I fly in two days from now on NK BMI-CDV', 'booking'],
#   ['Book a late flight San Juan Lansing the 22nd of next month', 'booking'],
#   ['any trips next month on the 25th Traverse City to PSG ?', 'booking'],
#   ['Anything Medford JAC 27 Jul 25 ?', 'booking'],
#   ['Could you reserve a SNA - HLN flight 10/7/25', 'booking'],
#   ['Anything from SHR to Liberal tomorrow night?', 'booking'],
#   ['Book anything JAX-SGU on 5-19', 'booking'],
#   ['Find OGS-SBN seats 3-11 pm', 'booking'],
#   ['Find a late flight Bozeman Bozeman the 20th of next month', 'booking'],
#   ['Find an early flight Pellston-Wrangell next Sun', 'booking'],
#   ['Would you book April 22 LAS - Oakland', 'booking'],
#   ['did you see anything the 15th of next month Nantucket Sanford ?',
#    'booking'],
#   ['Book anything from IAD to FNL seven days from now', 'booking'],
#   ['reserve CPR BDL 4-16-26', 'booking'],
#   ['Find an early flight from Atlantic City to Albany tomorrow', 'booking'],
#   ['book STL IMT 10-3 2025 and give me the PNR', 'booking'],
#   ['Do you have any trips November 27 SLN - Charlottesville ?', 'booking'],
#   ['Can I fly in one days from now on OH CVG-GCK', 'booking'],
#   ['create a PNR for 1-23 HYS-MSP', 'booking'],
#   ['Do you see any trips next Tue Casper-Appleton ?', 'booking'],
#   ['did you find anything tomorrow night from AMA to San Juan ?', 'booking'],
#   ['Rhinelander-MIA schedule the 28th of Nov flight', 'booking'],
#   ['check EAT - Crescent City September 10', 'booking'],
#   ['Check if I can fly back next week on United 1054', 'booking'],
#   ['How does Oct 21 2025 Cleveland APN look?', 'booking'],
#   ['rebook EV CWA-EAT for 2-21', 'booking'],
#   ['Make a reservation CIU MKE 6-27', 'booking'],
#   ['Could you schedule an early flight Raleigh-Nashville next Sun', 'booking'],
#   ['Anything from Norfolk to Panama City for early tomorrow?', 'booking'],
#   ['rebook G4 9439 departing tomorrow', 'booking'],
#   ['Try finding a flight next Tuesday Palm Springs - Atlantic City',
#    'booking'],
#   ['Book anything CHA to BNA for 2/11', 'booking'],
#   ['Can you find a flight TYS BWI 2-20-26', 'booking'],
#   ['Check if I can fly back next week on G4 PAH-BIH', 'booking'],
#   ['Try looking for Sioux Falls - Waterloo next Monday', 'booking'],
#   ['Could you book next month on the 13th Kona to DCA', 'booking'],
#   ['Look for travel Ogdensburg - Topeka next Saturday', 'booking'],
#   ['a late flight booking TTN - Aguadilla December 21 please', 'booking'],
#   ['What can you find ALS-CWA for 2-5', 'booking'],
#   ['schedule seats from Lubbock to Scottsbluff for early tomorrow', 'booking'],
#   ['Yakima-BIH book the 2nd of Dec flight', 'booking']],
#  392)

# %%
# Create a new csv file
with open('query_intent_booking_altered.csv', 'w', newline='') as csvfile:
  writer = csv.writer(csvfile)
  writer.writerows(altered_data)

# !ls
# Out:
# Airline_Delay_Cause.csv		  query_intent_booking_template.csv
# query_intent_booking_altered.csv  sample_data

# %%
# !cat query_intent_booking_altered.csv
# Out:
# query,intent
# Find ORD-ORH seats for 11-14,booking
# Anything Hagerstown-Austin next Sat ?,booking
# Check if I can fly back next week on HA FOE-CID,booking
# rebook Alaska 2797 for 11-20,booking
# Find a flight from Longview to Sun Valley tomorrow,booking
# See if I can fly out tomorrow on PSA 9866,booking
# Anything Columbia-DEC the 22nd of Feb ?,booking
# Try finding a flight the 28th of Dec Belleville-CIU,booking
# Will you schedule seats Del Rio-Butte next Sat,booking
# Find travel San Jose-DEN the 24th of Aug,booking
# Try finding an available flight tomorrow Binghamton to Cleveland,booking
# Is it possible to fly Minot to Hobbs next month on the 1st ?,booking
# Schedule AS RIC-INL for tomorrow night,booking
# did you find anything six days from now from HHH to SCK ?,booking
# Do you see any trips two days from now from SBN to LFT ?,booking
# Try looking for travel from SPN to ACV three days from now,booking
# See if I can fly out tomorrow on DL OME-GRR,booking
# Book an early flight Gulfport to El Paso tomorrow evening,booking
# Will you book seats Nantucket-Fairbanks next Thu,booking
# Find a late flight LNK - San Luis Obispo December 30,booking
# Can you find from San Luis Obispo to Newport News for early tomorrow,booking
# search available flights Champaign - Akron next Friday,booking
# Check if I can fly home next week Greenville-Huntsville on Alaska,booking
# See if I can fly out tomorrow on B6 ROA-DTW,booking
# Find a flight Juneau to MSP next month on the 24th,booking
# Look for Longview to APN next month on the 16th,booking
# any trips 1 Aug 25 Santa Fe ROC ?,booking
# schedule a flight Hartford - San Diego next Wednesday,booking
# Check if I can fly home next week on JetBlue VEL-ALS,booking
# Can you find Owensboro Fort Smith the 28th of next month,booking
# Book FWA to XNA on 2/19,booking
# a late flight scheduling SFB - Colorado Springs February 7 please,booking
# Find available flights Norfolk to Grand Rapids tomorrow evening,booking
# Find an early flight Kona to Bangor tomorrow evening,booking
# Look for travel Pocatello-Long Beach next Sun,booking
# Can I fly in ten days from now on Hawaiian ONT-MFR,booking
# Can you find Roswell to PSC next month on the 7th,booking
# Could you get a seat St. Cloud-STL the 28th of Mar,booking
# Schedule Mesa Kotzebue-King Salmon for early tomorrow morning,booking
# Try looking from Islip to Montrose for early tomorrow,booking
# Find HHH - EFD for 2/26/26,booking
# Find CNY-ABR 6-11,booking
# See if I can fly out tomorrow Atlanta-Richmond on AirTran,booking
# Anything from CLD to SHR ten days from now?,booking
# Are there any flights tomorrow night from BKG to Bellingham ?,booking
# rebook Southwest EVV-SMF for next Saturday,booking
# Schedule WN 1417 for early morning tomorrow,booking
# Are there any flights next Mon Ithaca-Concord ?,booking
# did you see anything October 17 MSY - Fayetteville ?,booking
# Book anything RDD - SPN on 7/27/25,booking
# check SWO to MRY next month on the 6th,booking
# Search for CHS-COU 9-29 morning,booking
# did you see anything nine days from now from MKG to EVV ?,booking
# Reserve Frontier 2017 for Jun 5,booking
# Look at MSY to DEC nine days from now,booking
# Try looking for Albany-Orlando next Sat,booking
# did you see anything tomorrow night from SMF to Albany ?,booking
# A reservation ECP FCA 3-18-26 please,booking
# Find FOE - LSE seats 4/14/26,booking
# Look for travel Pocatello Peoria the 28th of next month,booking
# Book a seat Charleston to AGS next month on the 9th,booking
# Find from ACT to OKC one days from now,booking
# Reserve OH 164 for 10 Sep,booking
# Do you see any trips the 28th of Feb Portland-MVY ?,booking
# Schedule Allegiant 9960 for late tomorrow,booking
# Is there anything 15 Sep 25 Grand Junction LAN ?,booking
# Are there any flights next month on the 5th Prescott to LBL ?,booking
# Do you have any trips next Sun Fayetteville-Minot ?,booking
# Check if I can fly back next week on Endeavor Moab-West Palm Beach,booking
# Are there any flights six days from now from SNA to SMX ?,booking
# Do you have any trips next month on the 27th Victoria to PWM ?,booking
# Reserve VX LBE-LBL for Sunday,booking
# Find travel Springfield to Fayetteville tomorrow afternoon,booking
# reserve the 27th of next month Sault Ste. Marie Punta Gorda,booking
# Book a flight Austin to Ogdensburg tomorrow evening,booking
# Check if I can fly back next week on VX 2575,booking
# Book seats from Stillwater to Chattanooga for early tomorrow,booking
# reserve HDN - CLL for 7/1/26,booking
# Can you find a flight GUC - LRD 4/8/26,booking
# Book an early flight from Fort Smith to Cody tomorrow,booking
# Would you reserve a PIT-GST flight 11-20 pm?,booking
# What can you find SPS EGE 1-20-26,booking
# Could you schedule next month on the 8th West Yellowstone to GCC,booking
# Schedule US SEA-SJC for early tomorrow morning,booking
# Can you reserve a SPI to MLI flight 7/29 after 6:00?,booking
# What are my chances of flying the 3rd of Apr San Jose-DAY,booking
# Find travel from FAR to Louisville tomorrow night,booking
# Schedule AirTran BFF-PSE for tomorrow night,booking
# Find a flight from LCH to Houston tomorrow night,booking
# any trips the 15th of next month Devils Lake Lubbock ?,booking
# reserve a Columbia-AKN flight the 8th of Aug,booking
# Can you find Atlanta-Ketchikan next Wed,booking
# Look for Harlingen Norfolk the 22nd of next month,booking
# schedule an early flight Portland - Killeen next Saturday,booking
# Find a DRT FOD trip 8-9-25,booking
# Please find a FCA-RHI trip 5-31 pm,booking
# did you see anything 7 May Salina EYW ?,booking
# Is there anything for early tomorrow from Scranton to North Bend ?,booking
# check February 16 FWA - Helena ?,booking
# Try finding ELP CHS 6-3-26,booking
# flight Cody to FAI schedule next month on the 1st,booking
# Please find a LYH-AKN trip 11-6 pm,booking
# did you see anything next Tue Amarillo-Sault Ste. Marie ?,booking
# Schedule Virgin PAE-TKI for late tomorrow,booking
# Book the 14th of May Gustavus-AUS,booking
# schedule anything SLN to SAT for 10/9,booking
# Find a flight ALS to APN 11/24,booking
# any trips the 20th of Aug Montgomery-OGG ?,booking
# query,intent
# reserve PPG to GRI on 7/4,booking
# Is there anything the 1st of next month Quincy Valdosta ?,booking
# Is there anything October 5 LAX - Pullman ?,booking
# Find a MSY-GCC trip for 11-12 late,booking
# Find a flight Paducah Plattsburgh the 13th of next month,booking
# reserve two days from now from BLI to EVV,booking
# schedule a flight from Great Falls to Williston tomorrow,booking
# Try looking for travel Knoxville to COS next month on the 8th,booking
# Reserve Horizon ABY-BJI for Friday,booking
# Book seats Mobile to Longview tomorrow afternoon,booking
# Try looking at RIC to Roswell for tomorrow night,booking
# any trips September 20 ILG - Wilmington ?,booking
# Do you have any trips the 16th of next month Aspen Petersburg ?,booking
# Find a flight Ogden-Chicago next Thu,booking
# Find anything LWS to CAE for 5/10,booking
# Find travel from Texarkana to Yakutat for early tomorrow,booking
# reserve a Twin Falls to Allentown flight tomorrow,booking
# Reserve Mesa BWI-BKG for 9 Feb,booking
# reserve a PPG - Rapid City flight on May 8,booking
# Book a seat Lafayette Charleston the 25th of next month,booking
# reserve GCK to LGA on 9 Mar and send me the record locator,booking
# Are there any flights tomorrow afternoon Daytona Beach to Baltimore ?,booking
# Are there any flights the 17th of Mar New Bern-HSV ?,booking
# schedule anything from LAR to HPN three days from now,booking
# check for a flight KTN-CIC 5-28 morning,booking
# Schedule American Eagle 4630 for tomorrow night,booking
# Book Aug 6 2025 Niagara Falls RST,booking
# any trips six days from now from IYK to DAY ?,booking
# did you find anything the 10th of next month Jacksonville Williston ?,booking
# Schedule 9E DSM-ABQ for late tomorrow,booking
# Reserve United Newark-Louisville for Monday,booking
# Is there anything next month on the 26th Champaign to CRW ?,booking
# Check if I can fly back next week on SkyWest 8144,booking
# Try looking for travel Harlingen-HIB the 27th of Jan,booking
# Check if I can fly out next week on Delta LFT-LAR,booking
# did you see anything the 19th of Apr Nantucket-EAU ?,booking
# Look for travel Indianapolis to Birmingham tomorrow afternoon,booking
# any trips for early tomorrow from Wenatchee to Allentown ?,booking
# Find a BWI-SIT trip 4-22 at night,booking
# rebook Endeavor 8305 arriving tomorrow,booking
# Schedule AA PHF-STT for early tomorrow morning,booking
# schedule an early flight Reno to Bristol tomorrow evening,booking
# Try finding a flight the 11th of next month Tucson Moab,booking
# reserve a EAR-PSG flight 6-13 at night,booking
# any flights tomorrow night from AVL to White Plains ?,booking
# check United tomorrow night from MBS to Detroit,booking
# Are there any flights 17 Nov 25 San Diego SWF ?,booking
# reserve CIC-OGG 5-14 am,booking
# Anything Niagara Falls to Portland tomorrow afternoon?,booking
# reserve IFP-PNS 9-28,booking
# Are there any flights the 20th of next month Bethel Eugene ?,booking
# Try finding COS-PNS 2-22 a.m.,booking
# Are there any flights next Thursday Evansville - Sanford ?,booking
# Do you see any trips June 6 PIR - Reno ?,booking
# Look for travel from Everett to Dallas for early tomorrow,booking
# Try reserving a San Diego Tallahassee flight the 7th of next month,booking
# schedule a flight Miami to Gulfport tomorrow evening,booking
# create a record locator MEI SPS 9/16,booking
# Look up San Diego CMX 28 Sep,booking
# Anything JLN - Melbourne December 7 ?,booking
# Find travel from RDM to MMH six days from now,booking
# Try finding a flight on August 14 RSW - Stillwater,booking
# Find BIH to MFR on 4/5,booking
# Ashland CIC schedule Nov 22 25,booking
# any trips next Saturday Belleville - Monterey ?,booking
# schedule a seat Stockton Fayetteville the 16th of next month,booking
# Try finding a flight next month on the 28th Williston to FAY,booking
# Find an early flight from OME to Richmond tomorrow night,booking
# Please find a ITO - MEM trip 9/15/25,booking
# Book three days from now from LRD to CEC,booking
# Do you have any trips six days from now from LRD to HSV ?,booking
# reserve MFE-CRP 12-20 a.m.,booking
# reserve a Cold Bay SNA flight Oct 12 2025,booking
# reserve on 3/17 RST to ELP,booking
# Can you find a flight SMX-BWI 5-13,booking
# schedule six days from now from DAL to RAP,booking
# Find a flight 13 May Roanoke USA,booking
# Can I fly in five days from now on JetBlue Milwaukee-Hagerstown,booking
# schedule a seat Grand Island-GRR the 24th of Jun,booking
# reserve a Columbia - Charlotte flight next Tuesday,booking
# Reserve Southwest Manchester-Fort Wayne for 19 Aug,booking
# reserve August 28 HTS - Salt Lake City,booking
# Find availability Colorado Springs-Laredo next Tue,booking
# schedule an early flight from Fort Wayne to Lewisburg tomorrow,booking
# check American next month on the 5th Evansville to BGR,booking
# Please find a RAP-DHN flight for 7-13 late,booking
# Try looking for Providence to Bristol tomorrow afternoon,booking
# Book a seat Cincinnati SIT Sep 18 2025,booking
# reserve a Cold Bay to HOB flight next month on the 25th,booking
# Find travel Philadelphia Bozeman the 22nd of next month,booking
# any trips next Tue Little Rock-Moline ?,booking
# Book SkyWest Chicago-State College for 10-30,booking
# schedule a late flight Kahului Nome the 2nd of next month,booking
# Reserve ExpressJet FLG-DRO for September 29,booking
# Find a flight Little Rock MLB Jul 5 26,booking
# Find VLD SHD seats 9-2-25,booking
# rebook MQ 1324 for 11-23,booking
# search availability EFD-PUB on 9-19,booking
# Find OWB - Wilmington February 7,booking
# Check if I can fly back next week CAE-GST on Frontier,booking
# Anything Pueblo Palm Springs the 16th of next month?,booking
# did you find anything the 10th of Jul Marquette-MSN ?,booking
# Reserve Delta 8978 for 2 Nov,booking
# any trips tomorrow afternoon Williston to Mobile ?,booking
# Book a flight from Albany to Jamestown tomorrow,booking
# Book an early flight from CLD to Quincy tomorrow night,booking
# Try finding HYS-BOS 12-26 early,booking
# Find West Yellowstone DCA 8 Mar,booking
# Find anything RIC-AVP on 11-28,booking
# rebook American 846 for next Saturday,booking
# did you find anything May 24 2026 Honolulu UIN ?,booking
# Make a reservation YNG to TVC on 10/15,booking
# Please reserve a Bethel-Mammoth Lakes flight next Fri,booking
# Look at PAE - Lake Charles August 26,booking
# Find availability CWA - Bloomington January 20,booking
# Try scheduling seats from CAE to Helena tomorrow night,booking
# Would you schedule August 24 OKC - Everett,booking
# See if I can fly out tomorrow on Spirit 9088,booking
# Find travel Texarkana SIT 16 Nov,booking
# Find a late flight Minneapolis-IAH the 22nd of Nov,booking
# Find anything GEG - SUX on 12/29/25,booking
# Schedule ExpressJet Dallas-Santa Fe for tomorrow night,booking
# Can I fly in nine days from now PAE-MQT on American Eagle,booking
# schedule COU to PSP on 11/3,booking
# Can you find Watertown - Alamosa next Tuesday,booking
# Can I fly home two days from now from Mobile to Sheridan on Frontier,booking
# Can you schedule seats Santa Barbara - San Antonio next Monday,booking
# See if I can fly out tomorrow MKE-XWA on F9,booking
# Check if I can fly back next week SDF-MGM on MQ,booking
# See if I can fly out tomorrow BLV-STL on Alaska,booking
# Can I fly in five days from now LBB-PIB on OO,booking
# Find ALB-BUF seats for 6-2 late,booking
# See if I can fly out tomorrow on YV 2277,booking
# Please find a ONT-ROA flight 6-23 at night,booking
# Can I fly in two days from now on Southwest 7450,booking
# Find a flight Plattsburgh-LGA the 18th of Dec,booking
# Book on 7/12 CWA to SCK,booking
# Can you find from SCE to Manchester tomorrow night,booking
# Search RAP-OGG 2-24 early,booking
# Book PSA Pellston-Pittsburgh for next Monday,booking
# schedule anything BDL - CHS on 5/2/26,booking
# check Delta for the 4th of next month Mosinee Traverse City,booking
# schedule a seat Great Falls FWA Oct 17 25,booking
# Do you have any trips tomorrow night from MLI to Lincoln ?,booking
# Find a late flight Gainesville BPT Jun 11 26,booking
# schedule seats Hays to Appleton tomorrow afternoon,booking
# Book anything ELP HOB for 7-16-25,booking
# Is there anything four days from now from AZA to PBG ?,booking
# check seats EGE-ESC 4-27 pm,booking
# Reserve Republic San Diego-Hibbing for October 20,booking
# reserve a SLN-TXK flight 9-15 p.m.,booking
# did you find anything next month on the 5th Riverton to PUB ?,booking
# schedule the 6th of Oct Durango-LFT,booking
# rebook United IMT-CID for tomorrow,booking
# Could you get me a flight from BTV to Raleigh tomorrow night,booking
# Is there anything tomorrow afternoon Nome to Kearney ?,booking
# Do you have any trips 24 Jun 2026 Lexington ABQ ?,booking
# Find a MRY-IAD flight 11-6 pm,booking
# Try finding a flight next Fri Decatur-Des Moines,booking
# reserve next month on the 26th Aguadilla to BWI,booking
# Are there any flights for early tomorrow from Laramie to Allentown ?,booking
# Is there anything next Thursday Dallas - Rhinelander ?,booking
# Can I fly Hilton Head FAY on 9 May,booking
# rebook Republic GTF-SCE for 2-5,booking
# Trenton BLI book Jul 10 2025,booking
# schedule an early flight from EFD to Tokeen tomorrow night,booking
# Is there anything the 14th of Apr Montrose-SHR ?,booking
# Find a JAX-PBI trip 5-3 p.m.,booking
# Find a EFD-SHV flight 7-24 pm,booking
# schedule Mar 2 26 Ponce ACV,booking
# Get two seats AZO - Burlington September 21,booking
# Check if I can fly back next week on EV 9522,booking
# Look for travel from RNO to Devils Lake tomorrow night,booking
# Is there anything next Sat Florence-Iron Mountain ?,booking
# Reserve US MCN-ISP for 17 Dec,booking
# Get a flight Scottsbluff-Hibbing next Thu,booking
# Schedule UA 5425 for late tomorrow,booking
# Will you reserve a SYR-FOE flight for 11-13,booking
# schedule a flight from EAR to Louisville tomorrow night,booking
# Book Spirit Cody-Alexandria for tomorrow,booking
# See if I can fly out tomorrow on US Sitka-Cleveland,booking
# rebook QX TKI-MSY for tomorrow,booking
# Find anything FAI ALW for 3-22-26,booking
# Reserve NK 9767 for Wednesday,booking
# Try looking for travel LGB - Minneapolis June 28,booking
# Book an early flight Pago Pago - Mobile next Tuesday,booking
# Check International Falls to Wichita Falls tomorrow afternoon,booking
# Please book the 4th of next month Pittsburgh Roanoke,booking
# Please schedule the 15th of next month Myrtle Beach Ashland,booking
# Reserve FL LGB-IAH for April 1,booking
# Can I fly in two days from now on Republic 581,booking
# Try booking seats from ENV to Mission tomorrow night,booking
# Can I fly in four days from now on Delta Bethel-Rochester,booking
# See if I can fly out tomorrow on American JAN-MLU,booking
# See if I can fly out tomorrow on Virgin Duluth-Sitka,booking
# Find an early flight Laredo - San Angelo next Friday,booking
# Find a flight 4/17 after 6:00 RHI to LYH,booking
# Schedule Hawaiian 7671 for early morning tomorrow,booking
# flight Fayetteville to FSM book next month on the 19th,booking
# Reserve OO 4224 for Nov 22,booking
# Can I fly in eight days from now on FL 4467,booking
# Find travel Bloomington - Carlsbad next Sunday,booking
# Find PGV-MHT seats 5-2 p.m.,booking
# Can you book seats Valdosta - Johnstown next Wednesday,booking
# Find a IMT-GNV flight 2-2 p.m.,booking
# i need a pnr for Vernal San Luis Obispo Sep 8th,booking
# reserve a GCC-LCK flight for 8-15 late,booking
# what can you find SBN-PIR 2-28 at night?,booking
# reserve a SHV-MBS flight 9-30 pm,booking
# Look up Newport News-ABR the 11th of Aug,booking
# see what's available LBL - Appleton May 5,booking
# Schedule YX 6962 for tomorrow night,booking
# Do you have any trips the 18th of Jul Fort Wayne-DVL ?,booking
# Can I fly in seven days from now on US 5145,booking
# book a pnr Erie-Rochester for next Tuesday afternoon,booking
# Anything Binghamton - Latrobe next Sunday ?,booking
# schedule a flight Joplin-Bristol next Wed,booking
# Is there anything tomorrow night from DBQ to Garden City ?,booking
# rebook HA 91 for next Friday,booking
# schedule on 11/8 SAV to CGI,booking
# Are there any flights February 7 LBE - Carlsbad ?,booking
# schedule a seat Omaha to PIH next month on the 24th,booking
# Find King Salmon-BOS the 9th of Nov,booking
# Can I fly in five days from now on Allegiant ABR-LBE,booking
# schedule anything IAD EAR for 10-18-25,booking
# See if I can fly out tomorrow on QX 9590,booking
# rebook YV SAN-WRG for next Tuesday,booking
# Schedule Horizon Panama City-Jackson for late tomorrow,booking
# Find a CAK-VEL flight for 6-11,booking
# Find JAC-ENV 2-9 am,booking
# Find anything from RIW to GPT seven days from now,booking
# Find travel Billings to ISP next month on the 16th,booking
# Book an early flight Fresno-Long Beach next Thu,booking
# See if I can fly out tomorrow on Endeavor SDF-CMX,booking
# Do you see any trips 12 Aug 2025 Rochester RDU ?,booking
# Reserve JetBlue 7779 for Thursday,booking
# Find a flight from PAE to GUM ten days from now,booking
# did you see anything next month on the 2nd Liberal to MCI ?,booking
# Check if I can fly back next week on American Spokane-Cheyenne,booking
# Book a flight Gustavus - Columbus next Tuesday,booking
# Find a HOU - CMI flight 1/2/26,booking
# Can I fly in two days from now on NK BMI-CDV,booking
# Book a late flight San Juan Lansing the 22nd of next month,booking
# any trips next month on the 25th Traverse City to PSG ?,booking
# Anything Medford JAC 27 Jul 25 ?,booking
# Could you reserve a SNA - HLN flight 10/7/25,booking
# Anything from SHR to Liberal tomorrow night?,booking
# Book anything JAX-SGU on 5-19,booking
# Find OGS-SBN seats 3-11 pm,booking
# Find a late flight Bozeman Bozeman the 20th of next month,booking
# Find an early flight Pellston-Wrangell next Sun,booking
# Would you book April 22 LAS - Oakland,booking
# did you see anything the 15th of next month Nantucket Sanford ?,booking
# Book anything from IAD to FNL seven days from now,booking
# reserve CPR BDL 4-16-26,booking
# Find an early flight from Atlantic City to Albany tomorrow,booking
# book STL IMT 10-3 2025 and give me the PNR,booking
# Do you have any trips November 27 SLN - Charlottesville ?,booking
# Can I fly in one days from now on OH CVG-GCK,booking
# create a PNR for 1-23 HYS-MSP,booking
# Do you see any trips next Tue Casper-Appleton ?,booking
# did you find anything tomorrow night from AMA to San Juan ?,booking
# Rhinelander-MIA schedule the 28th of Nov flight,booking
# check EAT - Crescent City September 10,booking
# Check if I can fly back next week on United 1054,booking
# How does Oct 21 2025 Cleveland APN look?,booking
# rebook EV CWA-EAT for 2-21,booking
# Make a reservation CIU MKE 6-27,booking
# Could you schedule an early flight Raleigh-Nashville next Sun,booking
# Anything from Norfolk to Panama City for early tomorrow?,booking
# rebook G4 9439 departing tomorrow,booking
# Try finding a flight next Tuesday Palm Springs - Atlantic City,booking
# Book anything CHA to BNA for 2/11,booking
# Can you find a flight TYS BWI 2-20-26,booking
# Check if I can fly back next week on G4 PAH-BIH,booking
# Try looking for Sioux Falls - Waterloo next Monday,booking
# Could you book next month on the 13th Kona to DCA,booking
# Look for travel Ogdensburg - Topeka next Saturday,booking
# a late flight booking TTN - Aguadilla December 21 please,booking
# What can you find ALS-CWA for 2-5,booking
# schedule seats from Lubbock to Scottsbluff for early tomorrow,booking
# Yakima-BIH book the 2nd of Dec flight,booking

# %%
# Save the file locally to my machine
from google.colab import files
files.download('query_intent_booking_altered.csv')
