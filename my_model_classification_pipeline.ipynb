# %% [markdown]
# ### Question best_model_bert in a classification pipeline

# %%
# !mkdir best_model_bert

# %%
# Upload best_model_bert files (takes several minutes)
# !ls -lh best_model_bert
# Out:
# total 419M
# -rw-r--r-- 1 root root  841 Jul 15 22:47 config.json
# -rw-r--r-- 1 root root 418M Jul 15 22:50 model.safetensors
# -rw-r--r-- 1 root root  125 Jul 15 22:47 special_tokens_map.json
# -rw-r--r-- 1 root root 1.2K Jul 15 22:47 tokenizer_config.json
# -rw-r--r-- 1 root root 695K Jul 15 22:47 tokenizer.json
# -rw-r--r-- 1 root root 5.3K Jul 15 22:47 training_args.bin
# -rw-r--r-- 1 root root 227K Jul 15 22:47 vocab.txt

# %%
# Create a classification pipeline
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

# Define ID to label mapping
id2label_mapping = {0: 'booking', 1: 'general', 2:'status'}

model_path = "best_model_bert"

model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    id2label=id2label_mapping
)
tokenizer = AutoTokenizer.from_pretrained(model_path)

question_classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

question = "How can I book a flight?"
question_classifier(question)
# Out:
# Device set to use cpu
# [{'label': 'general', 'score': 0.9892827272415161}]

# %%
question = "When does UA 504 arrive?"
question_classifier(question)
# Out:
# [{'label': 'status', 'score': 0.9935223460197449}]

# %%
question_classifier("Book me a flight for tomorrow night LAX-SEA")
# Out:
# [{'label': 'booking', 'score': 0.9965169429779053}]

# %%
question_classifier("what is my name")
# Out:
# [{'label': 'general', 'score': 0.9883416295051575}]

# %%
question_classifier("reserve dallas chicago next week")
# Out:
# [{'label': 'booking', 'score': 0.9963086247444153}]

# %%
question_classifier("how late is united 2")
# Out:
# [{'label': 'general', 'score': 0.9837002158164978}]

# %%
question_classifier("how late is united 23?")
# Out:
# [{'label': 'general', 'score': 0.8821864128112793}]

# %%
question_classifier("how late is united 232?")
# Out:
# [{'label': 'status', 'score': 0.9213180541992188}]

# %%
question_classifier("how late is united 232")
# Out:
# [{'label': 'status', 'score': 0.915716826915741}]

# %%
question_classifier("is united 2 late?")
# Out:
# [{'label': 'status', 'score': 0.9875125288963318}]

# %%
question_classifier("is united 2 late")
# Out:
# [{'label': 'status', 'score': 0.9899006485939026}]

# %% [markdown]
# ### Question checkpoint-225 in a classification pipeline

# %%
# !mkdir bert_chkpt-225

# %%
# Upload checkpoint-225 and wait (several minutes) for files to finish uploading
# !ls -lh bert_chkpt-225
# Out:
# total 1.3G
# -rw-r--r-- 1 root root  841 Jul 15 22:54 config.json
# -rw-r--r-- 1 root root 418M Jul 15 22:58 model.safetensors
# -rw-r--r-- 1 root root 836M Jul 15 23:01 optimizer.pt
# -rw-r--r-- 1 root root  14K Jul 15 22:54 rng_state.pth
# -rw-r--r-- 1 root root 1.1K Jul 15 22:54 scheduler.pt
# -rw-r--r-- 1 root root  125 Jul 15 22:54 special_tokens_map.json
# -rw-r--r-- 1 root root 1.2K Jul 15 22:54 tokenizer_config.json
# -rw-r--r-- 1 root root 695K Jul 15 22:54 tokenizer.json
# -rw-r--r-- 1 root root  12K Jul 15 22:54 trainer_state.json
# -rw-r--r-- 1 root root 5.2K Jul 15 22:54 training_args.bin
# -rw-r--r-- 1 root root 227K Jul 15 22:54 vocab.txt

# %%
# Create a classification pipeline
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

# Define ID to label mapping
id2label_mapping = {0: 'booking', 1: 'general', 2:'status'}

model_path = "bert_chkpt-225"

model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    id2label=id2label_mapping
)
tokenizer = AutoTokenizer.from_pretrained(model_path)

question_classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

question = "How can I book a flight?"
question_classifier(question)
# Out:
# Device set to use cpu
# [{'label': 'general', 'score': 0.9846746921539307}]

# %%
question_classifier("how late is united 2")
# Out:
# [{'label': 'status', 'score': 0.9124318361282349}]

# %%
question_classifier("how late is united 23")
# Out:
# [{'label': 'status', 'score': 0.9857354760169983}]

# %%
question_classifier("is united 2 late")
# Out:
# [{'label': 'status', 'score': 0.991881787776947}]

# %%
question_classifier(["is united 1 late", "how late is united 1?"])
# Out:
# [{'label': 'status', 'score': 0.990568995475769},
#  {'label': 'general', 'score': 0.9709840416908264}]

# %%
question_classifier(["is american 1 late", "how late is american 1"])
# Out:
# [{'label': 'status', 'score': 0.9855216145515442},
#  {'label': 'general', 'score': 0.9596443176269531}]

# %%
question_classifier(["how late is american 2", "how late is delta 1"])
# Out:
# [{'label': 'general', 'score': 0.9251183867454529},
#  {'label': 'general', 'score': 0.9667983651161194}]

# %%
question_classifier(["how late is american airlines 1", "how late is delta flight 1"])
# Out:
# [{'label': 'general', 'score': 0.6682505011558533},
#  {'label': 'general', 'score': 0.7187938690185547}]

# %%
question_classifier(["how late is american airlines 2", "how late is delta flight 2"])
# Out:
# [{'label': 'status', 'score': 0.6207279562950134},
#  {'label': 'status', 'score': 0.783605694770813}]

# %%
question_classifier(["is delta 1 late", "is american 1 late"])
# Out:
# [{'label': 'status', 'score': 0.9932147264480591},
#  {'label': 'status', 'score': 0.9855216145515442}]

# %%
question_classifier(["status of delta 1", "status of american 1"])
# Out:
# [{'label': 'status', 'score': 0.9813898205757141},
#  {'label': 'status', 'score': 0.9887421727180481}]

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'departure': {'iata': 'LAX'},  # wrong param should be dep_iata
    'arrival': {'iata': 'SEA'},    # wrong param should be arr_iata
    'limit': 10,
    #'flight': {'iata': 'UA2'}     # wrong parma should be flight_number
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

for flight in api_response['data']:
  print(f"flight: {flight['flight']['iata']}, arrival: {arrival['estimated']}")  # wrong arrival[] format, dict is flight[]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-69731915.py in <cell line: 0>()
#      15
#      16 for flight in api_response['data']:
# ---> 17   print(f"flight: {flight['flight']['iata']}, arrival: {arrival['estimated']}")
#
# NameError: name 'arrival' is not defined

# %%
for flight in api_response['data']:
  print(f"flight: {flight['flight']['iata']}, arrival: {flight['arrival']['estimated']}")
# Out:
# flight: JL35, arrival: 2025-07-16T05:56:00+00:00
# flight: QF5671, arrival: 2025-07-16T06:24:00+00:00
# flight: LX9042, arrival: 2025-07-16T04:54:00+00:00
# flight: OZ6797, arrival: 2025-07-16T04:54:00+00:00
# flight: SK8071, arrival: 2025-07-16T04:54:00+00:00
# flight: TK9316, arrival: 2025-07-16T04:54:00+00:00
# flight: UA7672, arrival: 2025-07-16T04:54:00+00:00
# flight: VA5525, arrival: 2025-07-16T04:54:00+00:00
# flight: 5J760, arrival: 2025-07-16T05:20:00+00:00
# flight: AA8952, arrival: 2025-07-16T08:53:00+00:00

# %%
for flight in api_response['data']:
  if flight['flight']['iata'] == 'UA7672':
    print(f"from: {flight['departure']['airport']}")
    print(f"to: {flight['arrival']['airport']}")
    print(f"departure delay: {flight['departure']['delay']}")
    print(f"departure actual: {flight['departure']['actual']}")
    print(f"departure terminal: {flight['departure']['terminal']}")
    print(f"departure gate: {flight['departure']['gate']}")
    print(f"arrival delay: {flight['arrival']['delay']}")
    print(f"arrival actual: {flight['arrival']['actual']}")
    print(f"arrival terminal: {flight['arrival']['terminal']}")
    print(f"arrival gate: {flight['arrival']['gate']}")
# Out:
# from: Singapore Changi
# to: Perth International
# departure delay: 16
# departure actual: 2025-07-16T00:21:00+00:00
# departure terminal: 3
# departure gate: A11
# arrival delay: None
# arrival actual: None
# arrival terminal: 1
# arrival gate: None

# %%
api_response
# Out:
# {'pagination': {'limit': 10, 'offset': 0, 'count': 10, 'total': 258096},
#  'data': [{'flight_date': '2025-07-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '3',
#     'gate': '108A',
#     'delay': 22,
#     'scheduled': '2025-07-16T00:05:00+00:00',
#     'estimated': '2025-07-16T00:05:00+00:00',
#     'actual': '2025-07-16T00:27:00+00:00',
#     'estimated_runway': '2025-07-16T00:27:00+00:00',
#     'actual_runway': '2025-07-16T00:27:00+00:00'},
#    'arrival': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '1',
#     'gate': 'D36',
#     'baggage': None,
#     'scheduled': '2025-07-16T06:10:00+00:00',
#     'delay': None,
#     'estimated': '2025-07-16T05:56:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
# ...

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'limit': 10,
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 10, 'offset': 0, 'count': 4, 'total': 4},
#  'data': [{'flight_date': '2025-07-15',
#    'flight_status': 'active',
#    'departure': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': '5',
#     'gate': '52H',
#     'delay': 7,
#     'scheduled': '2025-07-15T19:45:00+00:00',
#     'estimated': '2025-07-15T19:45:00+00:00',
#     'actual': '2025-07-15T19:51:00+00:00',
#     'estimated_runway': '2025-07-15T19:51:00+00:00',
#     'actual_runway': '2025-07-15T19:51:00+00:00'},
#    'arrival': {'airport': 'Denver International',
#     'timezone': 'America/Denver',
#     'iata': 'DEN',
#     'icao': 'KDEN',
#     'terminal': 'A',
#     'gate': 'C38',
#     'baggage': '7',
#     'scheduled': '2025-07-15T23:09:00+00:00',
#     'delay': None,
#     'estimated': '2025-07-15T22:47:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
# ...

# %%
for flight in api_response['data']:
  print(f"flight: {flight['flight']['iata']}, arrival: {flight['arrival']['estimated']}")
# Out:
# flight: QF3062, arrival: 2025-07-15T22:47:00+00:00
# flight: QR9531, arrival: 2025-07-15T22:47:00+00:00
# flight: TN1269, arrival: 2025-07-15T22:47:00+00:00
# flight: AA6256, arrival: 2025-07-15T22:47:00+00:00

# %%
for flight in api_response['data']:
  if flight['flight']['iata'] == 'AA6256':
    print(f"from: {flight['departure']['airport']}")
    print(f"to: {flight['arrival']['airport']}")
    print(f"departure delay: {flight['departure']['delay']}")
    print(f"departure actual: {flight['departure']['actual']}")
    print(f"departure terminal: {flight['departure']['terminal']}")
    print(f"departure gate: {flight['departure']['gate']}")
    print(f"arrival delay: {flight['arrival']['delay']}")
    print(f"arrival estimated: {flight['arrival']['estimated']}")
    print(f"arrival actual: {flight['arrival']['actual']}")
    print(f"arrival terminal: {flight['arrival']['terminal']}")
    print(f"arrival gate: {flight['arrival']['gate']}")
    print(f"baggage carrousel: {flight['arrival']['baggage']} ")
# Out:
# from: Los Angeles International
# to: Denver International
# departure delay: 7
# departure actual: 2025-07-15T19:51:00+00:00
# departure terminal: 5
# departure gate: 52H
# arrival delay: None
# arrival estimated: 2025-07-15T22:47:00+00:00
# arrival actual: None
# arrival terminal: A
# arrival gate: C38
# baggage carrousel: 7

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_number': 'WN1291',  # wrong need flight_iata
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_wn = api_result.json()

api_response_wn
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %% [markdown]
# Aviationstack's default behavior for the flights endpoint is to return a paginated response of currently active flights, in alphabetical order by default.
#
# If you're using the free plan or a lower-tier paid plan, you are limited to a maximum of 100 results per request.
#
# When you specify a flight_number as a filter, this filter is applied after the initial retrieval of the first 100 results. If the flight you're looking for falls outside of those initial 100 results, it won't be found.

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_iata': 'WN2574',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_wn = api_result.json()

api_response_wn
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %%
for flight in api_response_wn['data']:
  print(f"flight: {flight['flight']['iata']}, arrival: {flight['arrival']['estimated']}")

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_iata': 'WN2574',
    'arr_scheduled_time_arr': '2025-07-17'
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_wn = api_result.json()

api_response_wn
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Your current subscription plan does not support this API function.'}}

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_iata': 'WN2574',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_wn = api_result.json()

api_response_wn
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'landed',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_iata': 'UA1013',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'landed',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 19, 'total': 19},
#  'data': [{'flight_date': '2025-07-17',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': '8',
#     'gate': '81',
#     'delay': 18,
#     'scheduled': '2025-07-17T07:11:00+00:00',
#     'estimated': '2025-07-17T07:11:00+00:00',
#     'actual': '2025-07-17T07:28:00+00:00',
#     'estimated_runway': '2025-07-17T07:28:00+00:00',
#     'actual_runway': '2025-07-17T07:28:00+00:00'},
#    'arrival': {'airport': 'Denver International',
#     'timezone': 'America/Denver',
#     'iata': 'DEN',
#     'icao': 'KDEN',
#     'terminal': None,
#     'gate': 'B37',
#     'baggage': '14',
#     'scheduled': '2025-07-17T10:35:00+00:00',
#     'delay': None,
#     'estimated': '2025-07-17T10:19:00+00:00',
#     'actual': '2025-07-17T10:20:00+00:00',
# ...

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'landed',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
    'flight_iata': 'AS6147',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 1, 'total': 1},
#  'data': [{'flight_date': '2025-07-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': '5',
#     'gate': '52G',
#     'delay': 3,
#     'scheduled': '2025-07-16T19:45:00+00:00',
#     'estimated': '2025-07-16T19:45:00+00:00',
#     'actual': '2025-07-16T19:48:00+00:00',
#     'estimated_runway': '2025-07-16T19:48:00+00:00',
#     'actual_runway': '2025-07-16T19:48:00+00:00'},
#    'arrival': {'airport': 'Denver International',
#     'timezone': 'America/Denver',
#     'iata': 'DEN',
#     'icao': 'KDEN',
#     'terminal': 'B',
#     'gate': 'C36',
#     'baggage': '7',
#     'scheduled': '2025-07-16T23:09:00+00:00',
#     'delay': None,
#     'estimated': '2025-07-16T22:45:00+00:00',
#     'actual': '2025-07-16T22:40:00+00:00',
# ...

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'scheduled',
    'dep_iata': 'LAX',
    'arr_iata': 'DEN',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 11, 'total': 11},
#  'data': [{'flight_date': '2025-07-17',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Los Angeles International',
#     'timezone': 'America/Los_Angeles',
#     'iata': 'LAX',
#     'icao': 'KLAX',
#     'terminal': '1',
#     'gate': '18B',
#     'delay': None,
#     'scheduled': '2025-07-17T13:40:00+00:00',
#     'estimated': '2025-07-17T13:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Denver International',
#     'timezone': 'America/Denver',
#     'iata': 'DEN',
#     'icao': 'KDEN',
#     'terminal': '5',
#     'gate': 'C67',
#     'baggage': '2',
#     'scheduled': '2025-07-17T17:10:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Southwest Airlines', 'iata': 'WN', 'icao': 'SWA'},
# ...

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'DEN',
    'arr_iata': 'DFW',
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_dfw = api_result.json()

api_response_dfw
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 0, 'total': 0}, 'data': []}

# %%
import requests

params = {
    'access_key': '74cf73ec5294f9374eaf0ed308f76728',
    'flight_status': 'active',
    'dep_iata': 'DEN',
    'arr_iata': 'DFW',
    'flight_date': '2025-07-17'
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response_dfw = api_result.json()

api_response_dfw
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Your current subscription plan does not support this API function.'}}
